# %% [markdown]
# # MSL Recognition — Column 1 Run (Myanmar Text Labels)
#
# **Dataset:** MSL4Emergency (558 videos)
# **Label column:** Column 1 — Myanmar normal text phrase (e.g. `မီး ။`)
# **Models:** BiLSTM + Attention | Transformer Encoder | ST-GCN
# **Config:** `config/config_kaggle.yaml` (batch_size=64, num_workers=4)
#
# Pipeline:
# ```
# 01_prepare_data  →  02_extract_keypoints  →  03_augment_data
# →  04_train (bilstm)  →  04_train (transformer)  →  04_train (stgcn)
# →  05_evaluate (all 3)  →  Summary table
# ```

# %%
# ═══════════════════════════════════════════════════════════════
# CONFIGURATION — only change this cell to switch experiments
# ═══════════════════════════════════════════════════════════════
LABEL_COL   = 1                          # 1=Myanmar text, 2=MSL gloss
CONFIG      = 'config/config_kaggle.yaml'
EXP_PREFIX  = f'exp_col{LABEL_COL}'     # exp_col1_bilstm, exp_col1_transformer, ...

VIDEOS_INPUT = '/kaggle/input/datasets/theinkyawlwin/msl4emergency-videos'
CODE_INPUT   = '/kaggle/input/datasets/theinkyawlwin/msl4emergency-code'

print(f'Label column : {LABEL_COL}')
print(f'Exp prefix   : {EXP_PREFIX}')
print(f'Config       : {CONFIG}')
# Out:
# Label column : 1
# Exp prefix   : exp_col1
# Config       : config/config_kaggle.yaml

# %% [markdown]
# ## Step 0 — GPU & Environment Check

# %%
import torch
print(f'PyTorch  : {torch.__version__}')
print(f'CUDA     : {torch.cuda.is_available()}')
if torch.cuda.is_available():
    for i in range(torch.cuda.device_count()):
        props = torch.cuda.get_device_properties(i)
        print(f'  GPU {i} : {props.name}  ({props.total_memory // 1024**2} MiB)')
# !nvidia-smi
# Out:
# PyTorch  : 2.10.0+cu128
# CUDA     : True
#   GPU 0 : Tesla T4  (14911 MiB)
#   GPU 1 : Tesla T4  (14911 MiB)
# Sat Jul  4 09:13:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   44C    P8             10W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Step 1 — Install Dependencies

# %%
# Install dependencies (mediapipe 0.10.14 for legacy solutions + protobuf upgrade)
# !pip install --upgrade protobuf
# !pip install -q \
    mediapipe==0.10.14 \
    torchmetrics>=1.2.0 \
    seaborn>=0.13.0 \
    tqdm>=4.66.0
print('Dependencies installed.')
# Out:
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (5.29.5)
# Collecting protobuf
#   Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# grpcio-tools 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.35.1 which is incompatible.
# google-cloud-bigtable 2.36.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 7.35.1 which is incompatible.
# google-cloud-discoveryengine 0.13.12 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# google-cloud-aiplatform 1.148.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 7.35.1 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 7.35.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 7.35.1 which is incompatible.
# Successfully installed protobuf-7.35.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.39.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# grpcio-tools 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# a2a-sdk 0.3.26 requires protobuf>=5.29.5, but you have protobuf 4.25.9 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.9 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# Dependencies installed.

# %% [markdown]
# ## Step 2 — Setup Working Directory

# %%
import os, shutil
from pathlib import Path

# Copy pipeline code (src/, scripts/, config/, tools/) to working dir
print('Copying code from dataset...')
shutil.copytree(CODE_INPUT, '.', dirs_exist_ok=True)
print('  ✓ Code copied')

# Create data/ directory
os.makedirs('data', exist_ok=True)
os.makedirs('results/logs', exist_ok=True)

# Symlink videos — avoids copying 4.3 GB!
videos_src = f'{VIDEOS_INPUT}/video'
videos_dst = 'data/videos'
if not os.path.exists(videos_dst):
    os.symlink(videos_src, videos_dst)
    print(f'  ✓ Symlinked: {videos_dst} → {videos_src}')
else:
    print(f'  ✓ Symlink already exists: {videos_dst}')

# Copy annotations.txt
ann_src = f'{VIDEOS_INPUT}/annotations.txt'
ann_dst = 'data/annotations.txt'
shutil.copy(ann_src, ann_dst)
print(f'  ✓ Copied annotations.txt')

# Verify
n_videos = len(list(Path('data/videos').glob('*.mp4')))
print(f'\n  Videos found   : {n_videos}')
print(f'  Annotations    : {sum(1 for _ in open(ann_dst))}')

# Make scripts executable
# !chmod +x scripts/*.sh
print('  ✓ Scripts ready')
# Out:
# Copying code from dataset...
#   ✓ Code copied
#   ✓ Symlinked: data/videos → /kaggle/input/datasets/theinkyawlwin/msl4emergency-videos/video
#   ✓ Copied annotations.txt
#
#   Videos found   : 558
#   Annotations    : 558
#   ✓ Scripts ready

# %% [markdown]
# ## Step 3 — Prepare Data (label_col=1)

# %%
# %%bash -s "$LABEL_COL" "$CONFIG"
# LABEL_COL=$1
# CONFIG=$2
# LABEL_COL=$LABEL_COL CONFIG=$CONFIG bash scripts/01_prepare_data.sh
# Out:
# ============================================================
#  Step 1 — Data Preparation
# ============================================================
#  Video dir       : data/videos
#  Annotation file : data/annotations.txt
#  Config          : config/config_kaggle.yaml
#  Label column    : 1 (1=Myanmar text, 2=MSL gloss)
#
#  Found 0 videos and 558 annotation lines
#
# 2026-07-04 09:14:15 | INFO     | prepare_data | ============================================================
# 2026-07-04 09:14:15 | INFO     | prepare_data | MSL Data Preparation
# 2026-07-04 09:14:15 | INFO     | prepare_data | Label column  : 1 → normal_text (Myanmar phrase)
# 2026-07-04 09:14:15 | INFO     | prepare_data | ============================================================
# 2026-07-04 09:14:15 | INFO     | prepare_data | Parsing annotation file: data/annotations.txt
# 2026-07-04 09:14:15 | INFO     | prepare_data | Total annotation records: 558
# 2026-07-04 09:14:15 | INFO     | prepare_data | Vocabulary built: 556 unique classes
# 2026-07-04 09:14:15 | INFO     | prepare_data | Label map saved → data/label_map.json
# 2026-07-04 09:14:15 | INFO     | prepare_data | Matching videos from: data/videos
# 2026-07-04 09:14:16 | INFO     | prepare_data | NOTE: MSL4Emergency has ~1 video per sign class. The pipeline handles this via: (1) random (non-stratified) train/val/test split on raw videos, (2) heavy keypoint-space augmentation on training split only (20×), (3) val/test evaluated on original un-augmented keypoints. This is the standard approach for low-resource sign language research.
# 2026-07-04 09:14:16 | INFO     | prepare_data | Creating random train/val/test splits (1-sample-per-class safe) …
# WARNING:root:Most classes have only 1 sample(s) — stratified splitting is not possible. Falling back to RANDOM (non-stratified) split. This is expected for the MSL4Emergency dataset where each sign has exactly one video. Augmentation will be applied to training keypoints only.
# 2026-07-04 09:14:16 | INFO     | prepare_data | Creating 5-fold CV splits (standard KFold) …
# 2026-07-04 09:14:16 | INFO     | prepare_data | Verifying keypoint files …
# 2026-07-04 09:14:16 | INFO     | prepare_data | Keypoint verification: 0/558 found, 558 missing
# 2026-07-04 09:14:16 | WARNING  | prepare_data | Run extract_keypoints.py before training!
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-1.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-2.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-3.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-4.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-5.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-6.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-7.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/Idx20-8.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-9.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   Missing keypoints for: data/videos/idx20-10.mp4
# 2026-07-04 09:14:16 | WARNING  | prepare_data |   ... and 548 more
#
# ============================================================
# Dataset Statistics [full]
# ============================================================
#   Total samples    : 558
#   Classes (present): 556 / 556 total
#   Samples/class    : min=1, max=2, mean=1.00
#   Size distribution:
#     1 sample(s) per class :  554 classes  (99.6%)
#     2 sample(s) per class :    2 classes  (0.4%)
#
#   Sample listing (first 20 classes):
#     ဟို မှာ မီးလောင် နေ တယ် ။                  2
#     ဘယ်လို ဖြစ် တာ လဲ ။                        2
#     မီး ။                                      1
#     မီး ငြှိမ်း ။                              1
#     မီးချိတ် ။                                 1
#     မီးကပ် ။                                   1
#     ရေပုံး ။                                   1
#     သဲ အိတ် ။                                  1
#     မီးသတ်ဆေးဘူး ။                             1
#     မီးသတ်ရေကန် ။                              1
#     မီးလောင် လွယ် သော ပစ္စည်း များ ။           1
#     လောင်စာဆီ ။                                1
#     အမှိုက် ။                                  1
#     လျှပ်စစ် မီး ။                             1
#     ဂက်စ် မီး ။                                1
#     မီးကြွင်းမီးကျန် ။                         1
#     မီးခလုပ် ။                                 1
#     မီးခြစ် ။                                  1
#     ဖယောင်းတိုင် ။                             1
#     ခြင်ဆေးခွေ ။                               1
# ============================================================
#
#
# ============================================================
#   Data preparation complete!
# ============================================================
#   Annotation records : 558
#   Unique classes     : 556
#   Train samples      : 390  (→ augmented ×20 in next step)
#   Val   samples      : 84   (original keypoints only)
#   Test  samples      : 84   (original keypoints only)
#   K-Fold splits      : 5 folds  →  data/kfold_splits.json
#   Label map          : data/label_map.json
#   Splits file        : data/splits.json
#
#   ⚠  Note: ~1 video/class → random (non-stratified) split used.
#      Val/test may not cover all 556 classes — this is expected.
#      Evaluation metrics will reflect classes seen in each split.
# ============================================================
#
#
# ============================================================
#  Data preparation done!
#  Outputs:
#    data/label_map.json   ← class vocab
#    data/splits.json      ← train/val/test indices
#    data/kfold_splits.json← 5-fold CV splits
#  Next: run 02_extract_keypoints.sh
# ============================================================

# %% [markdown]
# ## Step 4 — Extract MediaPipe Keypoints (~20 min)
# Complexity=2 (most accurate). Already-extracted files are skipped on re-run.

# %%
# !bash scripts/02_extract_keypoints.sh
# Out:
# ============================================================
#  Step 2 — MediaPipe Holistic Keypoint Extraction
# ============================================================
#  Video dir     : data/videos
#  Output dir    : data/keypoints
#  Complexity    : 2
#  Overwrite     : false
#
#  Total videos  : 0
#
# Downloading model to /usr/local/lib/python3.12/dist-packages/mediapipe/modules/pose_landmark/pose_landmark_heavy.tflite
# Extracting keypoints:   0%|          | 0/558 [00:00<?, ?video/s]INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1783156474.511148     129 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1783156474.538002     130 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1783156474.615992     128 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1783156474.771009     128 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /usr/local/lib/python3.12/dist-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Extracting keypoints: 100%|██████████| 558/558 [2:10:48<00:00, 14.07s/video]
#
# =======================================================
#   Keypoint Extraction Summary
# =======================================================
#   total                       : 558
#   processed                   : 558
#   failed                      : 0
#   skipped                     : 0
#   seq_len_min                 : 50
#   seq_len_max                 : 387
#   seq_len_mean                : 130.56810035842295
#   seq_len_std                 : 55.11924044288601
#   seq_len_p50                 : 119.0
#   seq_len_p95                 : 241.14999999999998
#   lh_mean_presence            : 0.6177083457390997
#   rh_mean_presence            : 0.7130488627228297
# =======================================================
#
#
# ============================================================
#  Keypoint extraction complete!
#  Stats saved → data/keypoints/extraction_stats.json
#  Next: run 03_augment_data.sh
# ============================================================

# %% [markdown]
# ## Step 5 — Augment Data (aug_factor=20, all-class design)

# %%
# %%bash -s "$CONFIG"
# CONFIG=$1
# CONFIG=$CONFIG bash scripts/03_augment_data.sh
# Out:
# ============================================================
#  Step 3 — All-Class Offline Data Augmentation
# ============================================================
#  Strategy    : all 558 videos → train/val/test by aug type
#  Aug factor  : 20x
#    Train     : 19 aug copies × 558 = 10602 samples
#    Val       : 1 aug copy × 558 = 558 samples
#    Test      : 558 originals (no augmentation)
#  Class overlap: 100% across all splits
#
# Augmenting all classes: 100%|██████████| 558/558 [00:31<00:00, 17.61sign/s]
#
# ============================================================
#   Augmentation Complete (all-class design)
# ============================================================
#   Original videos   : 558
#   Aug factor        : 20  (train uses 19, val uses 1)
#   Train samples     : 10602  (augmented, all classes)
#   Val   samples     : 558   (augmented, all classes)
#   Test  samples     : 558   (original,  all classes)
#   Class overlap     : 100% across all splits
#   Manifest          : data/augmented/augmented_manifest.json
# ============================================================
#
#
# ============================================================
#  Augmentation done!  Manifest → data/augmented/augmented_manifest.json
#  Next: bash scripts/04_train.sh
# ============================================================

# %% [markdown]
# ## Step 6 — Train BiLSTM + Attention

# %%
# %%bash -s "$CONFIG" "$EXP_PREFIX"
# CONFIG=$1
# EXP_PREFIX=$2
# CONFIG=$CONFIG bash scripts/04_train.sh bilstm ${EXP_PREFIX}_bilstm
# Out:
# ============================================================
#  Training MSL Recognition Model
# ============================================================
#  Model      : bilstm
#  Experiment : exp_col1_bilstm
#  Config     : config/config_kaggle.yaml
#
#  Data: train=10602, val=558, test=558 (all-class design)
#
# [GPU]
# Tesla T4, 15360 MiB, 14909 MiB, 40
# Tesla T4, 15360 MiB, 14909 MiB, 47
#
# 2026-07-04 11:26:04 | INFO     | train | Experiment: exp_col1_bilstm  Model: bilstm
# 2026-07-04 11:26:04 | INFO     | train | Classes: 556
# 2026-07-04 11:26:05 | INFO     | train | Using all-class manifest: train=10602, val=558, test=558
# 2026-07-04 11:26:05 | INFO     | train | Model: bilstm  Params: 4,813,806
# 2026-07-04 11:26:10 | INFO     | train | Starting training…
#
# [DataLoaders]
#   Train: 10602 samples, 165 batches
#   Val:   558   samples, 9 batches
#   Test:  558  samples, 9 batches
#
# 2026-07-04 11:26:23 | INFO     | train | Epoch   1/150 | train loss=6.9903 top1=0.21% | val loss=6.5774 top1=0.52% top5=2.05% | lr=5.45e-05 | 13s
# 2026-07-04 11:26:23 | INFO     | train |   ★ New best val top-1: 0.52%
# 2026-07-04 11:26:35 | INFO     | train | Epoch   2/150 | train loss=6.5854 top1=0.38% | val loss=5.9230 top1=2.60% top5=8.61% | lr=1.04e-04 | 12s
# 2026-07-04 11:26:35 | INFO     | train |   ★ New best val top-1: 2.60%
# 2026-07-04 11:26:47 | INFO     | train | Epoch   3/150 | train loss=5.8585 top1=2.49% | val loss=5.0694 top1=11.45% top5=29.36% | lr=1.53e-04 | 11s
# 2026-07-04 11:26:47 | INFO     | train |   ★ New best val top-1: 11.45%
# 2026-07-04 11:26:58 | INFO     | train | Epoch   4/150 | train loss=4.9339 top1=11.35% | val loss=4.1467 top1=32.27% top5=57.22% | lr=2.03e-04 | 11s
# 2026-07-04 11:26:58 | INFO     | train |   ★ New best val top-1: 32.27%
# 2026-07-04 11:27:10 | INFO     | train | Epoch   5/150 | train loss=3.9425 top1=30.40% | val loss=3.2736 top1=52.36% top5=72.31% | lr=2.53e-04 | 12s
# 2026-07-04 11:27:10 | INFO     | train |   ★ New best val top-1: 52.36%
# 2026-07-04 11:27:22 | INFO     | train | Epoch   6/150 | train loss=3.0947 top1=51.17% | val loss=2.5867 top1=67.66% top5=81.27% | lr=3.02e-04 | 12s
# 2026-07-04 11:27:22 | INFO     | train |   ★ New best val top-1: 67.66%
# 2026-07-04 11:27:34 | INFO     | train | Epoch   7/150 | train loss=2.5053 top1=64.94% | val loss=2.2645 top1=71.14% top5=84.84% | lr=3.52e-04 | 11s
# 2026-07-04 11:27:34 | INFO     | train |   ★ New best val top-1: 71.14%
# 2026-07-04 11:27:46 | INFO     | train | Epoch   8/150 | train loss=2.1937 top1=72.51% | val loss=2.0614 top1=74.81% top5=89.07% | lr=4.01e-04 | 12s
# 2026-07-04 11:27:46 | INFO     | train |   ★ New best val top-1: 74.81%
# 2026-07-04 11:27:57 | INFO     | train | Epoch   9/150 | train loss=2.0158 top1=77.05% | val loss=2.0324 top1=76.62% top5=86.57% | lr=4.51e-04 | 12s
# 2026-07-04 11:27:58 | INFO     | train |   ★ New best val top-1: 76.62%
# 2026-07-04 11:28:09 | INFO     | train | Epoch  10/150 | train loss=1.8928 top1=80.00% | val loss=1.8755 top1=80.99% top5=91.22% | lr=5.00e-04 | 12s
# 2026-07-04 11:28:09 | INFO     | train |   ★ New best val top-1: 80.99%
# 2026-07-04 11:28:21 | INFO     | train | Epoch  11/150 | train loss=1.8123 top1=82.12% | val loss=1.8662 top1=80.36% top5=90.25% | lr=5.00e-04 | 11s
# 2026-07-04 11:28:33 | INFO     | train | Epoch  12/150 | train loss=1.7192 top1=85.09% | val loss=1.7673 top1=83.21% top5=91.57% | lr=5.00e-04 | 12s
# 2026-07-04 11:28:33 | INFO     | train |   ★ New best val top-1: 83.21%
# 2026-07-04 11:28:45 | INFO     | train | Epoch  13/150 | train loss=1.6315 top1=87.16% | val loss=1.7368 top1=85.22% top5=92.33% | lr=5.00e-04 | 12s
# 2026-07-04 11:28:45 | INFO     | train |   ★ New best val top-1: 85.22%
# 2026-07-04 11:28:57 | INFO     | train | Epoch  14/150 | train loss=1.5635 top1=89.41% | val loss=1.6934 top1=84.66% top5=93.20% | lr=4.99e-04 | 12s
# 2026-07-04 11:29:09 | INFO     | train | Epoch  15/150 | train loss=1.5074 top1=90.52% | val loss=1.6612 top1=85.57% top5=92.68% | lr=4.99e-04 | 12s
# 2026-07-04 11:29:09 | INFO     | train |   ★ New best val top-1: 85.57%
# 2026-07-04 11:29:20 | INFO     | train | Epoch  16/150 | train loss=1.4702 top1=91.19% | val loss=1.6143 top1=86.33% top5=93.72% | lr=4.98e-04 | 12s
# 2026-07-04 11:29:21 | INFO     | train |   ★ New best val top-1: 86.33%
# 2026-07-04 11:29:32 | INFO     | train | Epoch  17/150 | train loss=1.4265 top1=92.23% | val loss=1.6165 top1=87.27% top5=93.37% | lr=4.97e-04 | 12s
# 2026-07-04 11:29:32 | INFO     | train |   ★ New best val top-1: 87.27%
# 2026-07-04 11:29:44 | INFO     | train | Epoch  18/150 | train loss=1.3879 top1=93.00% | val loss=1.5633 top1=87.40% top5=94.07% | lr=4.97e-04 | 12s
# 2026-07-04 11:29:44 | INFO     | train |   ★ New best val top-1: 87.40%
# 2026-07-04 11:29:56 | INFO     | train | Epoch  19/150 | train loss=1.3616 top1=93.69% | val loss=1.5675 top1=87.37% top5=93.37% | lr=4.96e-04 | 12s
# 2026-07-04 11:30:08 | INFO     | train | Epoch  20/150 | train loss=1.3346 top1=94.31% | val loss=1.6217 top1=86.92% top5=93.37% | lr=4.95e-04 | 12s
# 2026-07-04 11:30:20 | INFO     | train | Epoch  21/150 | train loss=1.3111 top1=94.55% | val loss=1.5590 top1=87.68% top5=94.07% | lr=4.93e-04 | 12s
# 2026-07-04 11:30:20 | INFO     | train |   ★ New best val top-1: 87.68%
# 2026-07-04 11:30:32 | INFO     | train | Epoch  22/150 | train loss=1.2885 top1=95.10% | val loss=1.5185 top1=88.55% top5=94.76% | lr=4.92e-04 | 12s
# 2026-07-04 11:30:32 | INFO     | train |   ★ New best val top-1: 88.55%
# 2026-07-04 11:30:44 | INFO     | train | Epoch  23/150 | train loss=1.2777 top1=95.19% | val loss=1.5228 top1=88.90% top5=94.59% | lr=4.91e-04 | 12s
# 2026-07-04 11:30:44 | INFO     | train |   ★ New best val top-1: 88.90%
# 2026-07-04 11:30:56 | INFO     | train | Epoch  24/150 | train loss=1.2651 top1=95.49% | val loss=1.5346 top1=88.20% top5=93.72% | lr=4.89e-04 | 12s
# 2026-07-04 11:31:08 | INFO     | train | Epoch  25/150 | train loss=1.2408 top1=95.87% | val loss=1.4821 top1=89.76% top5=94.07% | lr=4.88e-04 | 12s
# 2026-07-04 11:31:08 | INFO     | train |   ★ New best val top-1: 89.76%
# 2026-07-04 11:31:19 | INFO     | train | Epoch  26/150 | train loss=1.2399 top1=95.76% | val loss=1.4562 top1=89.98% top5=95.28% | lr=4.86e-04 | 11s
# 2026-07-04 11:31:19 | INFO     | train |   ★ New best val top-1: 89.98%
# 2026-07-04 11:31:31 | INFO     | train | Epoch  27/150 | train loss=1.2064 top1=96.54% | val loss=1.4354 top1=91.22% top5=94.94% | lr=4.84e-04 | 12s
# 2026-07-04 11:31:31 | INFO     | train |   ★ New best val top-1: 91.22%
# 2026-07-04 11:31:43 | INFO     | train | Epoch  28/150 | train loss=1.2060 top1=96.38% | val loss=1.4689 top1=90.11% top5=94.94% | lr=4.83e-04 | 12s
# 2026-07-04 11:31:55 | INFO     | train | Epoch  29/150 | train loss=1.1901 top1=96.73% | val loss=1.4234 top1=90.56% top5=95.28% | lr=4.81e-04 | 12s
# 2026-07-04 11:32:06 | INFO     | train | Epoch  30/150 | train loss=1.1770 top1=97.07% | val loss=1.4537 top1=90.63% top5=95.11% | lr=4.79e-04 | 11s
# 2026-07-04 11:32:18 | INFO     | train | Epoch  31/150 | train loss=1.1739 top1=97.04% | val loss=1.4564 top1=90.29% top5=94.59% | lr=4.76e-04 | 12s
# 2026-07-04 11:32:30 | INFO     | train | Epoch  32/150 | train loss=1.1587 top1=97.26% | val loss=1.4181 top1=91.57% top5=95.46% | lr=4.74e-04 | 12s
# 2026-07-04 11:32:30 | INFO     | train |   ★ New best val top-1: 91.57%
# 2026-07-04 11:32:42 | INFO     | train | Epoch  33/150 | train loss=1.1515 top1=97.47% | val loss=1.4293 top1=91.57% top5=95.11% | lr=4.72e-04 | 12s
# 2026-07-04 11:32:54 | INFO     | train | Epoch  34/150 | train loss=1.1447 top1=97.48% | val loss=1.4588 top1=90.59% top5=94.41% | lr=4.69e-04 | 12s
# 2026-07-04 11:33:05 | INFO     | train | Epoch  35/150 | train loss=1.1371 top1=97.81% | val loss=1.4190 top1=91.33% top5=95.46% | lr=4.67e-04 | 12s
# 2026-07-04 11:33:17 | INFO     | train | Epoch  36/150 | train loss=1.1345 top1=97.72% | val loss=1.4005 top1=91.33% top5=95.80% | lr=4.64e-04 | 12s
# 2026-07-04 11:33:29 | INFO     | train | Epoch  37/150 | train loss=1.1236 top1=97.86% | val loss=1.4073 top1=91.05% top5=95.28% | lr=4.61e-04 | 12s
# 2026-07-04 11:33:41 | INFO     | train | Epoch  38/150 | train loss=1.1199 top1=97.96% | val loss=1.3919 top1=91.22% top5=95.35% | lr=4.59e-04 | 12s
# 2026-07-04 11:33:53 | INFO     | train | Epoch  39/150 | train loss=1.1128 top1=98.15% | val loss=1.3858 top1=91.74% top5=95.98% | lr=4.56e-04 | 12s
# 2026-07-04 11:33:53 | INFO     | train |   ★ New best val top-1: 91.74%
# 2026-07-04 11:34:05 | INFO     | train | Epoch  40/150 | train loss=1.1046 top1=98.18% | val loss=1.3972 top1=92.89% top5=95.46% | lr=4.53e-04 | 12s
# 2026-07-04 11:34:05 | INFO     | train |   ★ New best val top-1: 92.89%
# 2026-07-04 11:34:17 | INFO     | train | Epoch  41/150 | train loss=1.1053 top1=98.22% | val loss=1.4027 top1=92.44% top5=95.46% | lr=4.50e-04 | 12s
# 2026-07-04 11:34:29 | INFO     | train | Epoch  42/150 | train loss=1.0951 top1=98.34% | val loss=1.3564 top1=92.09% top5=95.80% | lr=4.46e-04 | 12s
# 2026-07-04 11:34:41 | INFO     | train | Epoch  43/150 | train loss=1.0928 top1=98.37% | val loss=1.3648 top1=92.78% top5=95.80% | lr=4.43e-04 | 12s
# 2026-07-04 11:34:53 | INFO     | train | Epoch  44/150 | train loss=1.0807 top1=98.77% | val loss=1.3689 top1=92.09% top5=95.80% | lr=4.40e-04 | 12s
# 2026-07-04 11:35:05 | INFO     | train | Epoch  45/150 | train loss=1.0815 top1=98.71% | val loss=1.3765 top1=92.44% top5=95.28% | lr=4.36e-04 | 12s
# 2026-07-04 11:35:17 | INFO     | train | Epoch  46/150 | train loss=1.0850 top1=98.60% | val loss=1.3703 top1=91.92% top5=96.22% | lr=4.33e-04 | 12s
# 2026-07-04 11:35:29 | INFO     | train | Epoch  47/150 | train loss=1.0725 top1=98.95% | val loss=1.3808 top1=92.09% top5=95.46% | lr=4.29e-04 | 12s
# 2026-07-04 11:35:41 | INFO     | train | Epoch  48/150 | train loss=1.0682 top1=99.06% | val loss=1.3484 top1=92.96% top5=95.80% | lr=4.26e-04 | 12s
# 2026-07-04 11:35:41 | INFO     | train |   ★ New best val top-1: 92.96%
# 2026-07-04 11:35:53 | INFO     | train | Epoch  49/150 | train loss=1.0705 top1=98.91% | val loss=1.3529 top1=92.44% top5=95.46% | lr=4.22e-04 | 11s
# 2026-07-04 11:36:04 | INFO     | train | Epoch  50/150 | train loss=1.0642 top1=98.99% | val loss=1.3521 top1=92.26% top5=95.80% | lr=4.18e-04 | 12s
# 2026-07-04 11:36:16 | INFO     | train | Epoch  51/150 | train loss=1.0577 top1=99.26% | val loss=1.3456 top1=92.96% top5=96.15% | lr=4.14e-04 | 12s
# 2026-07-04 11:36:27 | INFO     | train | Epoch  52/150 | train loss=1.0532 top1=99.30% | val loss=1.3521 top1=92.44% top5=96.04% | lr=4.10e-04 | 11s
# 2026-07-04 11:36:39 | INFO     | train | Epoch  53/150 | train loss=1.0527 top1=99.23% | val loss=1.3361 top1=92.96% top5=95.98% | lr=4.06e-04 | 12s
# 2026-07-04 11:36:51 | INFO     | train | Epoch  54/150 | train loss=1.0465 top1=99.55% | val loss=1.3488 top1=92.96% top5=95.28% | lr=4.02e-04 | 12s
# 2026-07-04 11:37:03 | INFO     | train | Epoch  55/150 | train loss=1.0487 top1=99.38% | val loss=1.3482 top1=93.13% top5=95.80% | lr=3.98e-04 | 12s
# 2026-07-04 11:37:03 | INFO     | train |   ★ New best val top-1: 93.13%
# 2026-07-04 11:37:15 | INFO     | train | Epoch  56/150 | train loss=1.0493 top1=99.37% | val loss=1.3449 top1=92.26% top5=95.63% | lr=3.94e-04 | 12s
# 2026-07-04 11:37:27 | INFO     | train | Epoch  57/150 | train loss=1.0453 top1=99.46% | val loss=1.3514 top1=93.13% top5=95.98% | lr=3.89e-04 | 12s
# 2026-07-04 11:37:39 | INFO     | train | Epoch  58/150 | train loss=1.0434 top1=99.39% | val loss=1.3822 top1=91.92% top5=95.11% | lr=3.85e-04 | 12s
# 2026-07-04 11:37:51 | INFO     | train | Epoch  59/150 | train loss=1.0439 top1=99.39% | val loss=1.3556 top1=92.96% top5=95.63% | lr=3.81e-04 | 12s
# 2026-07-04 11:38:03 | INFO     | train | Epoch  60/150 | train loss=1.0432 top1=99.34% | val loss=1.3397 top1=93.65% top5=95.98% | lr=3.76e-04 | 12s
# 2026-07-04 11:38:03 | INFO     | train |   ★ New best val top-1: 93.65%
# 2026-07-04 11:38:14 | INFO     | train | Epoch  61/150 | train loss=1.0378 top1=99.51% | val loss=1.3315 top1=93.20% top5=96.15% | lr=3.72e-04 | 12s
# 2026-07-04 11:38:26 | INFO     | train | Epoch  62/150 | train loss=1.0367 top1=99.52% | val loss=1.3390 top1=93.13% top5=95.80% | lr=3.67e-04 | 12s
# 2026-07-04 11:38:38 | INFO     | train | Epoch  63/150 | train loss=1.0353 top1=99.58% | val loss=1.3270 top1=93.48% top5=95.80% | lr=3.63e-04 | 12s
# 2026-07-04 11:38:50 | INFO     | train | Epoch  64/150 | train loss=1.0326 top1=99.61% | val loss=1.3333 top1=93.13% top5=96.15% | lr=3.58e-04 | 12s
# 2026-07-04 11:39:02 | INFO     | train | Epoch  65/150 | train loss=1.0297 top1=99.64% | val loss=1.3528 top1=92.96% top5=95.80% | lr=3.53e-04 | 12s
# 2026-07-04 11:39:14 | INFO     | train | Epoch  66/150 | train loss=1.0257 top1=99.76% | val loss=1.3288 top1=93.65% top5=95.63% | lr=3.48e-04 | 12s
# 2026-07-04 11:39:26 | INFO     | train | Epoch  67/150 | train loss=1.0221 top1=99.86% | val loss=1.3396 top1=92.78% top5=95.80% | lr=3.44e-04 | 12s
# 2026-07-04 11:39:38 | INFO     | train | Epoch  68/150 | train loss=1.0224 top1=99.79% | val loss=1.3230 top1=94.17% top5=96.15% | lr=3.39e-04 | 12s
# 2026-07-04 11:39:38 | INFO     | train |   ★ New best val top-1: 94.17%
# 2026-07-04 11:39:51 | INFO     | train | Epoch  69/150 | train loss=1.0182 top1=99.89% | val loss=1.3298 top1=93.30% top5=95.63% | lr=3.34e-04 | 12s
# 2026-07-04 11:40:03 | INFO     | train | Epoch  70/150 | train loss=1.0214 top1=99.74% | val loss=1.3266 top1=93.65% top5=96.22% | lr=3.29e-04 | 12s
# 2026-07-04 11:40:15 | INFO     | train | Epoch  71/150 | train loss=1.0175 top1=99.85% | val loss=1.3252 top1=93.48% top5=95.80% | lr=3.24e-04 | 12s
# 2026-07-04 11:40:27 | INFO     | train | Epoch  72/150 | train loss=1.0165 top1=99.87% | val loss=1.3474 top1=93.65% top5=95.63% | lr=3.19e-04 | 12s
# 2026-07-04 11:40:39 | INFO     | train | Epoch  73/150 | train loss=1.0228 top1=99.67% | val loss=1.3148 top1=93.65% top5=96.22% | lr=3.14e-04 | 12s
# 2026-07-04 11:40:51 | INFO     | train | Epoch  74/150 | train loss=1.0205 top1=99.73% | val loss=1.3031 top1=94.00% top5=96.22% | lr=3.09e-04 | 12s
# 2026-07-04 11:41:03 | INFO     | train | Epoch  75/150 | train loss=1.0179 top1=99.75% | val loss=1.3027 top1=93.65% top5=95.98% | lr=3.04e-04 | 12s
# 2026-07-04 11:41:15 | INFO     | train | Epoch  76/150 | train loss=1.0138 top1=99.89% | val loss=1.3123 top1=94.35% top5=95.98% | lr=2.99e-04 | 12s
# 2026-07-04 11:41:16 | INFO     | train |   ★ New best val top-1: 94.35%
# 2026-07-04 11:41:28 | INFO     | train | Epoch  77/150 | train loss=1.0118 top1=99.87% | val loss=1.3042 top1=94.00% top5=96.32% | lr=2.94e-04 | 12s
# 2026-07-04 11:41:40 | INFO     | train | Epoch  78/150 | train loss=1.0113 top1=99.91% | val loss=1.2953 top1=94.00% top5=96.57% | lr=2.89e-04 | 12s
# 2026-07-04 11:41:52 | INFO     | train | Epoch  79/150 | train loss=1.0099 top1=99.97% | val loss=1.3385 top1=93.83% top5=95.98% | lr=2.84e-04 | 12s
# 2026-07-04 11:42:04 | INFO     | train | Epoch  80/150 | train loss=1.0097 top1=99.88% | val loss=1.3192 top1=94.28% top5=96.39% | lr=2.78e-04 | 12s
# 2026-07-04 11:42:16 | INFO     | train | Epoch  81/150 | train loss=1.0100 top1=99.92% | val loss=1.3047 top1=93.83% top5=96.63% | lr=2.73e-04 | 12s
# 2026-07-04 11:42:28 | INFO     | train | Epoch  82/150 | train loss=1.0078 top1=99.93% | val loss=1.3080 top1=94.17% top5=96.22% | lr=2.68e-04 | 12s
# 2026-07-04 11:42:40 | INFO     | train | Epoch  83/150 | train loss=1.0086 top1=99.90% | val loss=1.3139 top1=94.00% top5=96.15% | lr=2.63e-04 | 12s
# 2026-07-04 11:42:52 | INFO     | train | Epoch  84/150 | train loss=1.0062 top1=99.96% | val loss=1.3074 top1=94.35% top5=95.80% | lr=2.58e-04 | 12s
# 2026-07-04 11:43:04 | INFO     | train | Epoch  85/150 | train loss=1.0044 top1=100.00% | val loss=1.3017 top1=94.52% top5=96.15% | lr=2.52e-04 | 12s
# 2026-07-04 11:43:04 | INFO     | train |   ★ New best val top-1: 94.52%
# 2026-07-04 11:43:16 | INFO     | train | Epoch  86/150 | train loss=1.0034 top1=100.00% | val loss=1.2896 top1=95.04% top5=95.98% | lr=2.47e-04 | 12s
# 2026-07-04 11:43:16 | INFO     | train |   ★ New best val top-1: 95.04%
# 2026-07-04 11:43:29 | INFO     | train | Epoch  87/150 | train loss=1.0032 top1=100.00% | val loss=1.3013 top1=94.17% top5=95.80% | lr=2.42e-04 | 12s
# 2026-07-04 11:43:41 | INFO     | train | Epoch  88/150 | train loss=1.0026 top1=99.99% | val loss=1.3069 top1=94.00% top5=96.15% | lr=2.37e-04 | 12s
# 2026-07-04 11:43:53 | INFO     | train | Epoch  89/150 | train loss=1.0021 top1=99.98% | val loss=1.2886 top1=94.35% top5=96.15% | lr=2.32e-04 | 12s
# 2026-07-04 11:44:05 | INFO     | train | Epoch  90/150 | train loss=1.0027 top1=99.98% | val loss=1.2827 top1=94.17% top5=96.15% | lr=2.27e-04 | 12s
# 2026-07-04 11:44:17 | INFO     | train | Epoch  91/150 | train loss=1.0031 top1=99.93% | val loss=1.2824 top1=95.04% top5=96.39% | lr=2.21e-04 | 12s
# 2026-07-04 11:44:30 | INFO     | train | Epoch  92/150 | train loss=1.0027 top1=99.93% | val loss=1.2981 top1=94.35% top5=96.15% | lr=2.16e-04 | 12s
# 2026-07-04 11:44:42 | INFO     | train | Epoch  93/150 | train loss=1.0047 top1=99.90% | val loss=1.2866 top1=94.52% top5=96.15% | lr=2.11e-04 | 12s
# 2026-07-04 11:44:54 | INFO     | train | Epoch  94/150 | train loss=1.0010 top1=99.98% | val loss=1.3085 top1=93.83% top5=96.15% | lr=2.06e-04 | 12s
# 2026-07-04 11:45:06 | INFO     | train | Epoch  95/150 | train loss=1.0010 top1=99.97% | val loss=1.2757 top1=94.87% top5=96.39% | lr=2.01e-04 | 12s
# 2026-07-04 11:45:18 | INFO     | train | Epoch  96/150 | train loss=0.9995 top1=100.00% | val loss=1.2847 top1=94.35% top5=96.32% | lr=1.96e-04 | 12s
# 2026-07-04 11:45:30 | INFO     | train | Epoch  97/150 | train loss=0.9997 top1=99.95% | val loss=1.3022 top1=94.52% top5=95.98% | lr=1.91e-04 | 12s
# 2026-07-04 11:45:42 | INFO     | train | Epoch  98/150 | train loss=1.0013 top1=99.91% | val loss=1.2901 top1=94.17% top5=96.15% | lr=1.86e-04 | 12s
# 2026-07-04 11:45:53 | INFO     | train | Epoch  99/150 | train loss=0.9988 top1=99.98% | val loss=1.2929 top1=94.35% top5=95.80% | lr=1.81e-04 | 12s
# 2026-07-04 11:46:06 | INFO     | train | Epoch 100/150 | train loss=0.9977 top1=99.98% | val loss=1.3049 top1=94.35% top5=95.80% | lr=1.76e-04 | 12s
# 2026-07-04 11:46:18 | INFO     | train | Epoch 101/150 | train loss=0.9973 top1=100.00% | val loss=1.2936 top1=94.17% top5=96.15% | lr=1.71e-04 | 12s
# 2026-07-04 11:46:29 | INFO     | train | Epoch 102/150 | train loss=0.9961 top1=100.00% | val loss=1.3007 top1=94.17% top5=95.98% | lr=1.66e-04 | 12s
# 2026-07-04 11:46:41 | INFO     | train | Epoch 103/150 | train loss=0.9957 top1=100.00% | val loss=1.3033 top1=94.52% top5=95.98% | lr=1.61e-04 | 12s
# 2026-07-04 11:46:53 | INFO     | train | Epoch 104/150 | train loss=0.9957 top1=100.00% | val loss=1.2925 top1=94.52% top5=96.15% | lr=1.57e-04 | 12s
# 2026-07-04 11:47:05 | INFO     | train | Epoch 105/150 | train loss=0.9948 top1=100.00% | val loss=1.2931 top1=94.52% top5=96.15% | lr=1.52e-04 | 12s
# 2026-07-04 11:47:17 | INFO     | train | Epoch 106/150 | train loss=0.9948 top1=100.00% | val loss=1.2932 top1=94.17% top5=96.39% | lr=1.47e-04 | 12s
# 2026-07-04 11:47:29 | INFO     | train | Epoch 107/150 | train loss=0.9944 top1=100.00% | val loss=1.2903 top1=94.52% top5=96.15% | lr=1.42e-04 | 12s
# 2026-07-04 11:47:41 | INFO     | train | Epoch 108/150 | train loss=0.9942 top1=100.00% | val loss=1.2918 top1=94.69% top5=96.15% | lr=1.38e-04 | 12s
# 2026-07-04 11:47:53 | INFO     | train | Epoch 109/150 | train loss=0.9941 top1=100.00% | val loss=1.3005 top1=94.52% top5=96.32% | lr=1.33e-04 | 12s
# 2026-07-04 11:48:05 | INFO     | train | Epoch 110/150 | train loss=0.9936 top1=100.00% | val loss=1.2966 top1=94.52% top5=95.98% | lr=1.29e-04 | 12s
# 2026-07-04 11:48:17 | INFO     | train | Epoch 111/150 | train loss=0.9932 top1=100.00% | val loss=1.2946 top1=94.17% top5=96.15% | lr=1.24e-04 | 12s
# 2026-07-04 11:48:17 | INFO     | train | Early stopping at epoch 111 (patience=25)
# 2026-07-04 11:48:17 | INFO     | train | Training complete. Best val top-1: 95.04%
# 2026-07-04 11:48:17 | INFO     | train | Best checkpoint: results/exp_col1_bilstm/checkpoints/best.pth
#
#   Total training time: 0h 22m 17s
#
# ============================================================
#  Training done!  → results/exp_col1_bilstm/
#  Next: bash scripts/05_evaluate.sh bilstm exp_col1_bilstm
# ============================================================

# %% [markdown]
# ## Step 7 — Train Transformer Encoder

# %%
# %%bash -s "$CONFIG" "$EXP_PREFIX"
# CONFIG=$1
# EXP_PREFIX=$2
# CONFIG=$CONFIG bash scripts/04_train.sh transformer ${EXP_PREFIX}_transformer
# Out:
# ============================================================
#  Training MSL Recognition Model
# ============================================================
#  Model      : transformer
#  Experiment : exp_col1_transformer
#  Config     : config/config_kaggle.yaml
#
#  Data: train=10602, val=558, test=558 (all-class design)
#
# [GPU]
# Tesla T4, 15360 MiB, 14909 MiB, 75
# Tesla T4, 15360 MiB, 14909 MiB, 35
#
# 2026-07-04 11:48:22 | INFO     | train | Experiment: exp_col1_transformer  Model: transformer
# 2026-07-04 11:48:22 | INFO     | train | Classes: 556
# 2026-07-04 11:48:23 | INFO     | train | Using all-class manifest: train=10602, val=558, test=558
# 2026-07-04 11:48:24 | INFO     | train | Model: transformer  Params: 3,362,030
# 2026-07-04 11:48:25 | INFO     | train | Starting training…
#
# [DataLoaders]
#   Train: 10602 samples, 165 batches
#   Val:   558   samples, 9 batches
#   Test:  558  samples, 9 batches
#
# 2026-07-04 11:48:36 | INFO     | train | Epoch   1/150 | train loss=6.3676 top1=0.22% | val loss=6.3542 top1=0.00% top5=1.22% | lr=5.45e-05 | 11s
# 2026-07-04 11:48:36 | INFO     | train |   ★ New best val top-1: 0.00%
# 2026-07-04 11:48:47 | INFO     | train | Epoch   2/150 | train loss=6.2554 top1=0.56% | val loss=6.0176 top1=2.43% top5=7.15% | lr=1.04e-04 | 11s
# 2026-07-04 11:48:47 | INFO     | train |   ★ New best val top-1: 2.43%
# 2026-07-04 11:48:58 | INFO     | train | Epoch   3/150 | train loss=5.7507 top1=3.89% | val loss=5.3963 top1=10.51% top5=32.10% | lr=1.53e-04 | 11s
# 2026-07-04 11:48:59 | INFO     | train |   ★ New best val top-1: 10.51%
# 2026-07-04 11:49:10 | INFO     | train | Epoch   4/150 | train loss=5.0950 top1=15.66% | val loss=4.6728 top1=34.11% top5=66.83% | lr=2.03e-04 | 11s
# 2026-07-04 11:49:10 | INFO     | train |   ★ New best val top-1: 34.11%
# 2026-07-04 11:49:21 | INFO     | train | Epoch   5/150 | train loss=4.3318 top1=40.06% | val loss=3.8028 top1=64.55% top5=87.51% | lr=2.53e-04 | 11s
# 2026-07-04 11:49:21 | INFO     | train |   ★ New best val top-1: 64.55%
# 2026-07-04 11:49:31 | INFO     | train | Epoch   6/150 | train loss=3.4373 top1=66.39% | val loss=2.8620 top1=80.99% top5=92.44% | lr=3.02e-04 | 11s
# 2026-07-04 11:49:32 | INFO     | train |   ★ New best val top-1: 80.99%
# 2026-07-04 11:49:42 | INFO     | train | Epoch   7/150 | train loss=2.5040 top1=83.32% | val loss=1.9957 top1=86.44% top5=95.63% | lr=3.52e-04 | 11s
# 2026-07-04 11:49:42 | INFO     | train |   ★ New best val top-1: 86.44%
# 2026-07-04 11:49:53 | INFO     | train | Epoch   8/150 | train loss=1.7919 top1=90.09% | val loss=1.5978 top1=90.46% top5=96.39% | lr=4.01e-04 | 11s
# 2026-07-04 11:49:53 | INFO     | train |   ★ New best val top-1: 90.46%
# 2026-07-04 11:50:04 | INFO     | train | Epoch   9/150 | train loss=1.4695 top1=92.47% | val loss=1.4418 top1=90.87% top5=95.70% | lr=4.51e-04 | 11s
# 2026-07-04 11:50:04 | INFO     | train |   ★ New best val top-1: 90.87%
# 2026-07-04 11:50:15 | INFO     | train | Epoch  10/150 | train loss=1.3478 top1=93.76% | val loss=1.3865 top1=92.23% top5=96.22% | lr=5.00e-04 | 11s
# 2026-07-04 11:50:15 | INFO     | train |   ★ New best val top-1: 92.23%
# 2026-07-04 11:50:26 | INFO     | train | Epoch  11/150 | train loss=1.2857 top1=94.89% | val loss=1.3522 top1=93.03% top5=96.22% | lr=5.00e-04 | 11s
# 2026-07-04 11:50:26 | INFO     | train |   ★ New best val top-1: 93.03%
# 2026-07-04 11:50:37 | INFO     | train | Epoch  12/150 | train loss=1.2430 top1=95.58% | val loss=1.3872 top1=92.33% top5=95.46% | lr=5.00e-04 | 11s
# 2026-07-04 11:50:48 | INFO     | train | Epoch  13/150 | train loss=1.2104 top1=96.05% | val loss=1.3254 top1=93.55% top5=96.22% | lr=5.00e-04 | 11s
# 2026-07-04 11:50:48 | INFO     | train |   ★ New best val top-1: 93.55%
# 2026-07-04 11:50:59 | INFO     | train | Epoch  14/150 | train loss=1.1784 top1=96.76% | val loss=1.3159 top1=93.37% top5=96.81% | lr=4.99e-04 | 11s
# 2026-07-04 11:51:11 | INFO     | train | Epoch  15/150 | train loss=1.1545 top1=97.40% | val loss=1.2936 top1=93.96% top5=96.91% | lr=4.99e-04 | 11s
# 2026-07-04 11:51:11 | INFO     | train |   ★ New best val top-1: 93.96%
# 2026-07-04 11:51:22 | INFO     | train | Epoch  16/150 | train loss=1.1347 top1=97.77% | val loss=1.3108 top1=94.17% top5=95.80% | lr=4.98e-04 | 12s
# 2026-07-04 11:51:22 | INFO     | train |   ★ New best val top-1: 94.17%
# 2026-07-04 11:51:34 | INFO     | train | Epoch  17/150 | train loss=1.1205 top1=98.23% | val loss=1.3006 top1=94.66% top5=96.57% | lr=4.97e-04 | 11s
# 2026-07-04 11:51:34 | INFO     | train |   ★ New best val top-1: 94.66%
# 2026-07-04 11:51:45 | INFO     | train | Epoch  18/150 | train loss=1.1042 top1=98.51% | val loss=1.2796 top1=94.48% top5=97.09% | lr=4.97e-04 | 11s
# 2026-07-04 11:51:55 | INFO     | train | Epoch  19/150 | train loss=1.0954 top1=98.60% | val loss=1.2774 top1=94.31% top5=97.33% | lr=4.96e-04 | 11s
# 2026-07-04 11:52:06 | INFO     | train | Epoch  20/150 | train loss=1.0788 top1=99.14% | val loss=1.2593 top1=94.66% top5=97.68% | lr=4.95e-04 | 11s
# 2026-07-04 11:52:17 | INFO     | train | Epoch  21/150 | train loss=1.0696 top1=99.23% | val loss=1.2664 top1=94.76% top5=96.84% | lr=4.93e-04 | 11s
# 2026-07-04 11:52:17 | INFO     | train |   ★ New best val top-1: 94.76%
# 2026-07-04 11:52:28 | INFO     | train | Epoch  22/150 | train loss=1.0617 top1=99.31% | val loss=1.2574 top1=94.94% top5=97.09% | lr=4.92e-04 | 11s
# 2026-07-04 11:52:28 | INFO     | train |   ★ New best val top-1: 94.94%
# 2026-07-04 11:52:39 | INFO     | train | Epoch  23/150 | train loss=1.0534 top1=99.51% | val loss=1.2500 top1=95.35% top5=97.33% | lr=4.91e-04 | 11s
# 2026-07-04 11:52:39 | INFO     | train |   ★ New best val top-1: 95.35%
# 2026-07-04 11:52:50 | INFO     | train | Epoch  24/150 | train loss=1.0493 top1=99.59% | val loss=1.2415 top1=95.52% top5=97.15% | lr=4.89e-04 | 11s
# 2026-07-04 11:52:50 | INFO     | train |   ★ New best val top-1: 95.52%
# 2026-07-04 11:53:01 | INFO     | train | Epoch  25/150 | train loss=1.0391 top1=99.78% | val loss=1.2195 top1=95.42% top5=97.33% | lr=4.88e-04 | 11s
# 2026-07-04 11:53:12 | INFO     | train | Epoch  26/150 | train loss=1.0401 top1=99.62% | val loss=1.2190 top1=95.52% top5=97.15% | lr=4.86e-04 | 11s
# 2026-07-04 11:53:23 | INFO     | train | Epoch  27/150 | train loss=1.0413 top1=99.60% | val loss=1.2373 top1=95.35% top5=97.33% | lr=4.84e-04 | 11s
# 2026-07-04 11:53:34 | INFO     | train | Epoch  28/150 | train loss=1.0362 top1=99.67% | val loss=1.2362 top1=95.00% top5=97.33% | lr=4.83e-04 | 11s
# 2026-07-04 11:53:44 | INFO     | train | Epoch  29/150 | train loss=1.0399 top1=99.55% | val loss=1.2345 top1=95.77% top5=97.33% | lr=4.81e-04 | 11s
# 2026-07-04 11:53:45 | INFO     | train |   ★ New best val top-1: 95.77%
# 2026-07-04 11:53:55 | INFO     | train | Epoch  30/150 | train loss=1.0365 top1=99.71% | val loss=1.2183 top1=95.70% top5=97.33% | lr=4.79e-04 | 11s
# 2026-07-04 11:54:06 | INFO     | train | Epoch  31/150 | train loss=1.0232 top1=99.88% | val loss=1.2005 top1=95.87% top5=97.50% | lr=4.76e-04 | 11s
# 2026-07-04 11:54:06 | INFO     | train |   ★ New best val top-1: 95.87%
# 2026-07-04 11:54:17 | INFO     | train | Epoch  32/150 | train loss=1.0225 top1=99.86% | val loss=1.1893 top1=96.46% top5=97.50% | lr=4.74e-04 | 11s
# 2026-07-04 11:54:17 | INFO     | train |   ★ New best val top-1: 96.46%
# 2026-07-04 11:54:28 | INFO     | train | Epoch  33/150 | train loss=1.0227 top1=99.79% | val loss=1.2105 top1=96.11% top5=97.33% | lr=4.72e-04 | 11s
# 2026-07-04 11:54:39 | INFO     | train | Epoch  34/150 | train loss=1.0272 top1=99.65% | val loss=1.2264 top1=95.87% top5=97.33% | lr=4.69e-04 | 11s
# 2026-07-04 11:54:50 | INFO     | train | Epoch  35/150 | train loss=1.0210 top1=99.84% | val loss=1.1892 top1=96.22% top5=97.50% | lr=4.67e-04 | 11s
# 2026-07-04 11:55:01 | INFO     | train | Epoch  36/150 | train loss=1.0151 top1=99.88% | val loss=1.1919 top1=96.22% top5=97.50% | lr=4.64e-04 | 11s
# 2026-07-04 11:55:12 | INFO     | train | Epoch  37/150 | train loss=1.0200 top1=99.73% | val loss=1.2086 top1=95.63% top5=97.50% | lr=4.61e-04 | 11s
# 2026-07-04 11:55:23 | INFO     | train | Epoch  38/150 | train loss=1.0203 top1=99.78% | val loss=1.1945 top1=96.29% top5=97.50% | lr=4.59e-04 | 11s
# 2026-07-04 11:55:33 | INFO     | train | Epoch  39/150 | train loss=1.0145 top1=99.85% | val loss=1.1867 top1=96.22% top5=97.50% | lr=4.56e-04 | 11s
# 2026-07-04 11:55:44 | INFO     | train | Epoch  40/150 | train loss=1.0220 top1=99.76% | val loss=1.1993 top1=95.94% top5=97.50% | lr=4.53e-04 | 11s
# 2026-07-04 11:55:55 | INFO     | train | Epoch  41/150 | train loss=1.0129 top1=99.89% | val loss=1.2086 top1=95.52% top5=97.50% | lr=4.50e-04 | 11s
# 2026-07-04 11:56:06 | INFO     | train | Epoch  42/150 | train loss=1.0155 top1=99.76% | val loss=1.1892 top1=96.74% top5=97.68% | lr=4.46e-04 | 11s
# 2026-07-04 11:56:06 | INFO     | train |   ★ New best val top-1: 96.74%
# 2026-07-04 11:56:17 | INFO     | train | Epoch  43/150 | train loss=1.0127 top1=99.74% | val loss=1.1851 top1=96.04% top5=97.68% | lr=4.43e-04 | 11s
# 2026-07-04 11:56:28 | INFO     | train | Epoch  44/150 | train loss=1.0052 top1=99.88% | val loss=1.1910 top1=95.77% top5=97.33% | lr=4.40e-04 | 11s
# 2026-07-04 11:56:39 | INFO     | train | Epoch  45/150 | train loss=1.0062 top1=99.87% | val loss=1.1907 top1=96.11% top5=97.50% | lr=4.36e-04 | 11s
# 2026-07-04 11:56:50 | INFO     | train | Epoch  46/150 | train loss=1.0078 top1=99.83% | val loss=1.1832 top1=95.98% top5=97.85% | lr=4.33e-04 | 11s
# 2026-07-04 11:57:00 | INFO     | train | Epoch  47/150 | train loss=1.0149 top1=99.75% | val loss=1.2044 top1=96.29% top5=97.85% | lr=4.29e-04 | 11s
# 2026-07-04 11:57:11 | INFO     | train | Epoch  48/150 | train loss=1.0237 top1=99.60% | val loss=1.2136 top1=95.80% top5=97.68% | lr=4.26e-04 | 11s
# 2026-07-04 11:57:22 | INFO     | train | Epoch  49/150 | train loss=1.0050 top1=99.93% | val loss=1.1765 top1=96.22% top5=97.43% | lr=4.22e-04 | 11s
# 2026-07-04 11:57:33 | INFO     | train | Epoch  50/150 | train loss=1.0077 top1=99.76% | val loss=1.1794 top1=96.63% top5=97.68% | lr=4.18e-04 | 11s
# 2026-07-04 11:57:44 | INFO     | train | Epoch  51/150 | train loss=0.9997 top1=99.91% | val loss=1.1704 top1=96.29% top5=97.85% | lr=4.14e-04 | 11s
# 2026-07-04 11:57:55 | INFO     | train | Epoch  52/150 | train loss=0.9943 top1=99.98% | val loss=1.1623 top1=96.46% top5=97.68% | lr=4.10e-04 | 11s
# 2026-07-04 11:58:06 | INFO     | train | Epoch  53/150 | train loss=0.9921 top1=99.98% | val loss=1.1570 top1=96.63% top5=97.68% | lr=4.06e-04 | 11s
# 2026-07-04 11:58:17 | INFO     | train | Epoch  54/150 | train loss=0.9916 top1=99.97% | val loss=1.1561 top1=96.81% top5=97.50% | lr=4.02e-04 | 11s
# 2026-07-04 11:58:17 | INFO     | train |   ★ New best val top-1: 96.81%
# 2026-07-04 11:58:27 | INFO     | train | Epoch  55/150 | train loss=0.9891 top1=99.99% | val loss=1.1562 top1=96.63% top5=97.50% | lr=3.98e-04 | 11s
# 2026-07-04 11:58:38 | INFO     | train | Epoch  56/150 | train loss=0.9884 top1=100.00% | val loss=1.1657 top1=96.39% top5=97.50% | lr=3.94e-04 | 11s
# 2026-07-04 11:58:49 | INFO     | train | Epoch  57/150 | train loss=0.9882 top1=99.99% | val loss=1.1603 top1=96.63% top5=97.68% | lr=3.89e-04 | 11s
# 2026-07-04 11:59:00 | INFO     | train | Epoch  58/150 | train loss=0.9907 top1=99.95% | val loss=1.1765 top1=96.63% top5=97.50% | lr=3.85e-04 | 11s
# 2026-07-04 11:59:11 | INFO     | train | Epoch  59/150 | train loss=0.9939 top1=99.91% | val loss=1.1791 top1=96.29% top5=97.50% | lr=3.81e-04 | 11s
# 2026-07-04 11:59:22 | INFO     | train | Epoch  60/150 | train loss=1.0000 top1=99.82% | val loss=1.1775 top1=96.11% top5=97.33% | lr=3.76e-04 | 11s
# 2026-07-04 11:59:32 | INFO     | train | Epoch  61/150 | train loss=1.0006 top1=99.77% | val loss=1.1972 top1=95.80% top5=97.33% | lr=3.72e-04 | 11s
# 2026-07-04 11:59:43 | INFO     | train | Epoch  62/150 | train loss=0.9990 top1=99.89% | val loss=1.1849 top1=96.15% top5=97.09% | lr=3.67e-04 | 11s
# 2026-07-04 11:59:54 | INFO     | train | Epoch  63/150 | train loss=1.0042 top1=99.76% | val loss=1.2006 top1=95.87% top5=97.26% | lr=3.63e-04 | 11s
# 2026-07-04 12:00:05 | INFO     | train | Epoch  64/150 | train loss=1.0047 top1=99.78% | val loss=1.1711 top1=96.46% top5=97.68% | lr=3.58e-04 | 11s
# 2026-07-04 12:00:16 | INFO     | train | Epoch  65/150 | train loss=0.9955 top1=99.92% | val loss=1.1704 top1=96.39% top5=97.43% | lr=3.53e-04 | 11s
# 2026-07-04 12:00:27 | INFO     | train | Epoch  66/150 | train loss=0.9891 top1=99.99% | val loss=1.1607 top1=96.81% top5=97.50% | lr=3.48e-04 | 11s
# 2026-07-04 12:00:38 | INFO     | train | Epoch  67/150 | train loss=0.9878 top1=99.98% | val loss=1.1600 top1=96.63% top5=97.50% | lr=3.44e-04 | 11s
# 2026-07-04 12:00:48 | INFO     | train | Epoch  68/150 | train loss=0.9858 top1=99.99% | val loss=1.1592 top1=96.63% top5=97.50% | lr=3.39e-04 | 11s
# 2026-07-04 12:00:59 | INFO     | train | Epoch  69/150 | train loss=0.9842 top1=100.00% | val loss=1.1642 top1=96.39% top5=97.50% | lr=3.34e-04 | 11s
# 2026-07-04 12:01:10 | INFO     | train | Epoch  70/150 | train loss=0.9837 top1=100.00% | val loss=1.1626 top1=96.39% top5=97.68% | lr=3.29e-04 | 11s
# 2026-07-04 12:01:21 | INFO     | train | Epoch  71/150 | train loss=0.9829 top1=100.00% | val loss=1.1586 top1=96.39% top5=97.68% | lr=3.24e-04 | 11s
# 2026-07-04 12:01:32 | INFO     | train | Epoch  72/150 | train loss=0.9821 top1=100.00% | val loss=1.1602 top1=96.63% top5=97.50% | lr=3.19e-04 | 11s
# 2026-07-04 12:01:43 | INFO     | train | Epoch  73/150 | train loss=0.9819 top1=100.00% | val loss=1.1597 top1=96.63% top5=97.68% | lr=3.14e-04 | 11s
# 2026-07-04 12:01:54 | INFO     | train | Epoch  74/150 | train loss=0.9815 top1=100.00% | val loss=1.1615 top1=96.63% top5=97.50% | lr=3.09e-04 | 11s
# 2026-07-04 12:02:05 | INFO     | train | Epoch  75/150 | train loss=0.9813 top1=100.00% | val loss=1.1595 top1=96.63% top5=97.50% | lr=3.04e-04 | 11s
# 2026-07-04 12:02:15 | INFO     | train | Epoch  76/150 | train loss=0.9808 top1=100.00% | val loss=1.1569 top1=96.39% top5=97.33% | lr=2.99e-04 | 11s
# 2026-07-04 12:02:26 | INFO     | train | Epoch  77/150 | train loss=0.9805 top1=100.00% | val loss=1.1615 top1=96.39% top5=97.50% | lr=2.94e-04 | 11s
# 2026-07-04 12:02:37 | INFO     | train | Epoch  78/150 | train loss=0.9801 top1=100.00% | val loss=1.1491 top1=96.63% top5=97.68% | lr=2.89e-04 | 11s
# 2026-07-04 12:02:48 | INFO     | train | Epoch  79/150 | train loss=0.9802 top1=100.00% | val loss=1.1549 top1=96.39% top5=97.68% | lr=2.84e-04 | 11s
# 2026-07-04 12:02:48 | INFO     | train | Early stopping at epoch 79 (patience=25)
# 2026-07-04 12:02:48 | INFO     | train | Training complete. Best val top-1: 96.81%
# 2026-07-04 12:02:48 | INFO     | train | Best checkpoint: results/exp_col1_transformer/checkpoints/best.pth
#
#   Total training time: 0h 14m 30s
#
# ============================================================
#  Training done!  → results/exp_col1_transformer/
#  Next: bash scripts/05_evaluate.sh transformer exp_col1_transformer
# ============================================================

# %% [markdown]
# ## Step 8 — Train ST-GCN

# %%
# %%bash -s "$CONFIG" "$EXP_PREFIX"
# CONFIG=$1
# EXP_PREFIX=$2
# CONFIG=$CONFIG bash scripts/04_train.sh stgcn ${EXP_PREFIX}_stgcn
# Out:
# ============================================================
#  Training MSL Recognition Model
# ============================================================
#  Model      : stgcn
#  Experiment : exp_col1_stgcn
#  Config     : config/config_kaggle.yaml
#
#  Data: train=10602, val=558, test=558 (all-class design)
#
# [GPU]
# Tesla T4, 15360 MiB, 14909 MiB, 75
# Tesla T4, 15360 MiB, 14909 MiB, 35
#
# 2026-07-04 12:02:53 | INFO     | train | Experiment: exp_col1_stgcn  Model: stgcn
# 2026-07-04 12:02:53 | INFO     | train | Classes: 556
# 2026-07-04 12:02:55 | INFO     | train | Using all-class manifest: train=10602, val=558, test=558
# 2026-07-04 12:02:55 | INFO     | train | Model: stgcn  Params: 2,780,143
# 2026-07-04 12:02:56 | INFO     | train | Starting training…
#
# [DataLoaders]
#   Train: 10602 samples, 165 batches
#   Val:   558   samples, 9 batches
#   Test:  558  samples, 9 batches
#
# 2026-07-04 12:05:37 | INFO     | train | Epoch   1/150 | train loss=6.9783 top1=0.12% | val loss=6.5573 top1=0.17% top5=0.94% | lr=5.45e-05 | 161s
# 2026-07-04 12:05:37 | INFO     | train |   ★ New best val top-1: 0.17%
# 2026-07-04 12:08:14 | INFO     | train | Epoch   2/150 | train loss=6.4714 top1=0.24% | val loss=6.2390 top1=0.42% top5=2.46% | lr=1.04e-04 | 157s
# 2026-07-04 12:08:14 | INFO     | train |   ★ New best val top-1: 0.42%
# 2026-07-04 12:10:52 | INFO     | train | Epoch   3/150 | train loss=6.2149 top1=0.62% | val loss=5.9406 top1=2.05% top5=7.94% | lr=1.53e-04 | 158s
# 2026-07-04 12:10:52 | INFO     | train |   ★ New best val top-1: 2.05%
# 2026-07-04 12:13:31 | INFO     | train | Epoch   4/150 | train loss=5.9397 top1=1.54% | val loss=5.5219 top1=4.06% top5=16.13% | lr=2.03e-04 | 159s
# 2026-07-04 12:13:31 | INFO     | train |   ★ New best val top-1: 4.06%
# 2026-07-04 12:16:09 | INFO     | train | Epoch   5/150 | train loss=5.5732 top1=3.26% | val loss=4.9882 top1=7.22% top5=26.06% | lr=2.53e-04 | 158s
# 2026-07-04 12:16:09 | INFO     | train |   ★ New best val top-1: 7.22%
# 2026-07-04 12:18:47 | INFO     | train | Epoch   6/150 | train loss=5.1643 top1=6.01% | val loss=4.5579 top1=18.24% top5=42.85% | lr=3.02e-04 | 158s
# 2026-07-04 12:18:47 | INFO     | train |   ★ New best val top-1: 18.24%
# 2026-07-04 12:21:26 | INFO     | train | Epoch   7/150 | train loss=4.7399 top1=11.27% | val loss=4.1023 top1=30.92% top5=63.22% | lr=3.52e-04 | 159s
# 2026-07-04 12:21:26 | INFO     | train |   ★ New best val top-1: 30.92%
# 2026-07-04 12:24:06 | INFO     | train | Epoch   8/150 | train loss=4.2910 top1=18.81% | val loss=3.7234 top1=37.61% top5=71.82% | lr=4.01e-04 | 160s
# 2026-07-04 12:24:06 | INFO     | train |   ★ New best val top-1: 37.61%
# 2026-07-04 12:26:45 | INFO     | train | Epoch   9/150 | train loss=3.8258 top1=29.16% | val loss=3.3334 top1=54.82% top5=79.81% | lr=4.51e-04 | 159s
# 2026-07-04 12:26:45 | INFO     | train |   ★ New best val top-1: 54.82%
# 2026-07-04 12:29:25 | INFO     | train | Epoch  10/150 | train loss=3.4050 top1=40.88% | val loss=2.8169 top1=68.87% top5=87.75% | lr=5.00e-04 | 159s
# 2026-07-04 12:29:25 | INFO     | train |   ★ New best val top-1: 68.87%
# 2026-07-04 12:32:04 | INFO     | train | Epoch  11/150 | train loss=3.0129 top1=51.62% | val loss=2.5285 top1=70.19% top5=90.14% | lr=5.00e-04 | 159s
# 2026-07-04 12:32:04 | INFO     | train |   ★ New best val top-1: 70.19%
# 2026-07-04 12:34:42 | INFO     | train | Epoch  12/150 | train loss=2.6641 top1=62.97% | val loss=2.3783 top1=75.19% top5=90.84% | lr=5.00e-04 | 159s
# 2026-07-04 12:34:42 | INFO     | train |   ★ New best val top-1: 75.19%
# 2026-07-04 12:37:20 | INFO     | train | Epoch  13/150 | train loss=2.4121 top1=70.80% | val loss=2.2155 top1=79.11% top5=92.29% | lr=5.00e-04 | 158s
# 2026-07-04 12:37:20 | INFO     | train |   ★ New best val top-1: 79.11%
# 2026-07-04 12:39:59 | INFO     | train | Epoch  14/150 | train loss=2.2209 top1=76.11% | val loss=2.1531 top1=77.89% top5=92.16% | lr=4.99e-04 | 159s
# 2026-07-04 12:42:38 | INFO     | train | Epoch  15/150 | train loss=2.0748 top1=80.76% | val loss=2.0788 top1=78.03% top5=92.64% | lr=4.99e-04 | 159s
# 2026-07-04 12:45:17 | INFO     | train | Epoch  16/150 | train loss=1.9856 top1=82.83% | val loss=1.9052 top1=86.47% top5=95.52% | lr=4.98e-04 | 159s
# 2026-07-04 12:45:17 | INFO     | train |   ★ New best val top-1: 86.47%
# 2026-07-04 12:47:56 | INFO     | train | Epoch  17/150 | train loss=1.8796 top1=85.41% | val loss=1.7718 top1=87.47% top5=94.48% | lr=4.97e-04 | 158s
# 2026-07-04 12:47:56 | INFO     | train |   ★ New best val top-1: 87.47%
# 2026-07-04 12:50:33 | INFO     | train | Epoch  18/150 | train loss=1.8167 top1=87.06% | val loss=1.7697 top1=87.75% top5=95.24% | lr=4.97e-04 | 157s
# 2026-07-04 12:50:33 | INFO     | train |   ★ New best val top-1: 87.75%
# 2026-07-04 12:53:10 | INFO     | train | Epoch  19/150 | train loss=1.7687 top1=88.30% | val loss=1.7671 top1=86.12% top5=94.24% | lr=4.96e-04 | 157s
# 2026-07-04 12:55:48 | INFO     | train | Epoch  20/150 | train loss=1.7125 top1=89.64% | val loss=1.7152 top1=89.14% top5=94.94% | lr=4.95e-04 | 158s
# 2026-07-04 12:55:48 | INFO     | train |   ★ New best val top-1: 89.14%
# 2026-07-04 12:58:26 | INFO     | train | Epoch  21/150 | train loss=1.6834 top1=89.92% | val loss=1.7409 top1=85.84% top5=95.59% | lr=4.93e-04 | 157s
# 2026-07-04 13:01:05 | INFO     | train | Epoch  22/150 | train loss=1.6437 top1=91.16% | val loss=1.6530 top1=89.73% top5=95.77% | lr=4.92e-04 | 159s
# 2026-07-04 13:01:05 | INFO     | train |   ★ New best val top-1: 89.73%
# 2026-07-04 13:03:43 | INFO     | train | Epoch  23/150 | train loss=1.6117 top1=91.44% | val loss=1.6386 top1=89.31% top5=96.35% | lr=4.91e-04 | 158s
# 2026-07-04 13:06:21 | INFO     | train | Epoch  24/150 | train loss=1.5842 top1=91.76% | val loss=1.6490 top1=89.55% top5=95.07% | lr=4.89e-04 | 158s
# 2026-07-04 13:08:59 | INFO     | train | Epoch  25/150 | train loss=1.5627 top1=92.48% | val loss=1.6160 top1=89.03% top5=95.42% | lr=4.88e-04 | 158s
# 2026-07-04 13:11:38 | INFO     | train | Epoch  26/150 | train loss=1.5273 top1=93.15% | val loss=1.6020 top1=90.59% top5=96.35% | lr=4.86e-04 | 158s
# 2026-07-04 13:11:38 | INFO     | train |   ★ New best val top-1: 90.59%
# 2026-07-04 13:14:18 | INFO     | train | Epoch  27/150 | train loss=1.5025 top1=93.87% | val loss=1.5975 top1=91.12% top5=95.42% | lr=4.84e-04 | 160s
# 2026-07-04 13:14:18 | INFO     | train |   ★ New best val top-1: 91.12%
# 2026-07-04 13:16:56 | INFO     | train | Epoch  28/150 | train loss=1.4878 top1=94.11% | val loss=1.5994 top1=91.64% top5=95.00% | lr=4.83e-04 | 158s
# 2026-07-04 13:16:56 | INFO     | train |   ★ New best val top-1: 91.64%
# 2026-07-04 13:19:34 | INFO     | train | Epoch  29/150 | train loss=1.4718 top1=94.32% | val loss=1.5495 top1=90.77% top5=96.63% | lr=4.81e-04 | 158s
# 2026-07-04 13:22:13 | INFO     | train | Epoch  30/150 | train loss=1.4559 top1=94.40% | val loss=1.5283 top1=91.64% top5=96.63% | lr=4.79e-04 | 158s
# 2026-07-04 13:24:51 | INFO     | train | Epoch  31/150 | train loss=1.4312 top1=95.08% | val loss=1.5634 top1=91.12% top5=96.46% | lr=4.76e-04 | 158s
# 2026-07-04 13:27:30 | INFO     | train | Epoch  32/150 | train loss=1.4146 top1=95.37% | val loss=1.5006 top1=91.81% top5=96.29% | lr=4.74e-04 | 159s
# 2026-07-04 13:27:30 | INFO     | train |   ★ New best val top-1: 91.81%
# 2026-07-04 13:30:08 | INFO     | train | Epoch  33/150 | train loss=1.4132 top1=95.24% | val loss=1.5529 top1=90.25% top5=95.94% | lr=4.72e-04 | 158s
# 2026-07-04 13:32:45 | INFO     | train | Epoch  34/150 | train loss=1.3954 top1=95.59% | val loss=1.4935 top1=91.05% top5=96.63% | lr=4.69e-04 | 157s
# 2026-07-04 13:35:22 | INFO     | train | Epoch  35/150 | train loss=1.3815 top1=96.04% | val loss=1.4880 top1=91.98% top5=97.15% | lr=4.67e-04 | 157s
# 2026-07-04 13:35:22 | INFO     | train |   ★ New best val top-1: 91.98%
# 2026-07-04 13:38:00 | INFO     | train | Epoch  36/150 | train loss=1.3674 top1=96.13% | val loss=1.4953 top1=91.12% top5=95.77% | lr=4.64e-04 | 158s
# 2026-07-04 13:40:38 | INFO     | train | Epoch  37/150 | train loss=1.3539 top1=96.32% | val loss=1.5233 top1=91.12% top5=96.39% | lr=4.61e-04 | 158s
# 2026-07-04 13:43:17 | INFO     | train | Epoch  38/150 | train loss=1.3457 top1=96.46% | val loss=1.4747 top1=92.23% top5=96.11% | lr=4.59e-04 | 159s
# 2026-07-04 13:43:17 | INFO     | train |   ★ New best val top-1: 92.23%
# 2026-07-04 13:45:55 | INFO     | train | Epoch  39/150 | train loss=1.3366 top1=96.74% | val loss=1.4621 top1=92.33% top5=96.04% | lr=4.56e-04 | 158s
# 2026-07-04 13:45:55 | INFO     | train |   ★ New best val top-1: 92.33%
# 2026-07-04 13:48:33 | INFO     | train | Epoch  40/150 | train loss=1.3275 top1=96.86% | val loss=1.4921 top1=90.29% top5=96.04% | lr=4.53e-04 | 158s
# 2026-07-04 13:51:11 | INFO     | train | Epoch  41/150 | train loss=1.3145 top1=97.20% | val loss=1.4537 top1=91.98% top5=96.57% | lr=4.50e-04 | 158s
# 2026-07-04 13:53:49 | INFO     | train | Epoch  42/150 | train loss=1.3045 top1=97.23% | val loss=1.4480 top1=92.33% top5=96.91% | lr=4.46e-04 | 158s
# 2026-07-04 13:56:26 | INFO     | train | Epoch  43/150 | train loss=1.2957 top1=97.41% | val loss=1.4486 top1=91.46% top5=97.09% | lr=4.43e-04 | 157s
# 2026-07-04 13:59:04 | INFO     | train | Epoch  44/150 | train loss=1.2914 top1=97.49% | val loss=1.4671 top1=91.12% top5=96.22% | lr=4.40e-04 | 158s
# 2026-07-04 14:01:41 | INFO     | train | Epoch  45/150 | train loss=1.2834 top1=97.37% | val loss=1.4754 top1=91.29% top5=95.80% | lr=4.36e-04 | 157s
# 2026-07-04 14:04:18 | INFO     | train | Epoch  46/150 | train loss=1.2787 top1=97.69% | val loss=1.4406 top1=93.72% top5=96.91% | lr=4.33e-04 | 157s
# 2026-07-04 14:04:18 | INFO     | train |   ★ New best val top-1: 93.72%
# 2026-07-04 14:06:54 | INFO     | train | Epoch  47/150 | train loss=1.2673 top1=97.60% | val loss=1.4494 top1=92.16% top5=96.39% | lr=4.29e-04 | 157s
# 2026-07-04 14:09:31 | INFO     | train | Epoch  48/150 | train loss=1.2571 top1=97.99% | val loss=1.4570 top1=92.85% top5=97.15% | lr=4.26e-04 | 157s
# 2026-07-04 14:12:08 | INFO     | train | Epoch  49/150 | train loss=1.2590 top1=98.01% | val loss=1.4312 top1=92.50% top5=97.02% | lr=4.22e-04 | 157s
# 2026-07-04 14:14:44 | INFO     | train | Epoch  50/150 | train loss=1.2483 top1=98.13% | val loss=1.4388 top1=92.50% top5=96.63% | lr=4.18e-04 | 157s
# 2026-07-04 14:17:21 | INFO     | train | Epoch  51/150 | train loss=1.2389 top1=98.34% | val loss=1.4325 top1=93.13% top5=96.50% | lr=4.14e-04 | 156s
# 2026-07-04 14:19:58 | INFO     | train | Epoch  52/150 | train loss=1.2391 top1=98.22% | val loss=1.4064 top1=92.68% top5=96.74% | lr=4.10e-04 | 157s
# 2026-07-04 14:22:34 | INFO     | train | Epoch  53/150 | train loss=1.2322 top1=98.18% | val loss=1.4122 top1=92.96% top5=96.57% | lr=4.06e-04 | 156s
# 2026-07-04 14:25:12 | INFO     | train | Epoch  54/150 | train loss=1.2304 top1=98.41% | val loss=1.4145 top1=93.03% top5=96.91% | lr=4.02e-04 | 158s
# 2026-07-04 14:27:49 | INFO     | train | Epoch  55/150 | train loss=1.2239 top1=98.54% | val loss=1.4160 top1=93.20% top5=96.57% | lr=3.98e-04 | 157s
# 2026-07-04 14:30:27 | INFO     | train | Epoch  56/150 | train loss=1.2183 top1=98.63% | val loss=1.4164 top1=92.68% top5=96.39% | lr=3.94e-04 | 158s
# 2026-07-04 14:33:04 | INFO     | train | Epoch  57/150 | train loss=1.2145 top1=98.74% | val loss=1.4138 top1=93.20% top5=97.15% | lr=3.89e-04 | 157s
# 2026-07-04 14:35:40 | INFO     | train | Epoch  58/150 | train loss=1.2060 top1=98.75% | val loss=1.4429 top1=92.50% top5=97.09% | lr=3.85e-04 | 156s
# 2026-07-04 14:38:17 | INFO     | train | Epoch  59/150 | train loss=1.2023 top1=98.79% | val loss=1.4088 top1=93.20% top5=96.74% | lr=3.81e-04 | 157s
# 2026-07-04 14:40:53 | INFO     | train | Epoch  60/150 | train loss=1.1993 top1=98.84% | val loss=1.4042 top1=93.72% top5=96.91% | lr=3.76e-04 | 156s
# 2026-07-04 14:43:29 | INFO     | train | Epoch  61/150 | train loss=1.1918 top1=99.05% | val loss=1.4145 top1=92.85% top5=95.80% | lr=3.72e-04 | 156s
# 2026-07-04 14:46:05 | INFO     | train | Epoch  62/150 | train loss=1.1941 top1=98.89% | val loss=1.4115 top1=92.68% top5=96.84% | lr=3.67e-04 | 156s
# 2026-07-04 14:48:42 | INFO     | train | Epoch  63/150 | train loss=1.1879 top1=99.06% | val loss=1.3981 top1=92.33% top5=96.74% | lr=3.63e-04 | 156s
# 2026-07-04 14:51:19 | INFO     | train | Epoch  64/150 | train loss=1.1825 top1=99.13% | val loss=1.4132 top1=93.03% top5=96.57% | lr=3.58e-04 | 157s
# 2026-07-04 14:53:55 | INFO     | train | Epoch  65/150 | train loss=1.1808 top1=99.20% | val loss=1.4021 top1=93.03% top5=96.22% | lr=3.53e-04 | 156s
# 2026-07-04 14:56:30 | INFO     | train | Epoch  66/150 | train loss=1.1760 top1=99.15% | val loss=1.4031 top1=93.89% top5=96.32% | lr=3.48e-04 | 156s
# 2026-07-04 14:56:30 | INFO     | train |   ★ New best val top-1: 93.89%
# 2026-07-04 14:59:06 | INFO     | train | Epoch  67/150 | train loss=1.1754 top1=99.33% | val loss=1.4043 top1=93.03% top5=96.04% | lr=3.44e-04 | 156s
# 2026-07-04 15:01:42 | INFO     | train | Epoch  68/150 | train loss=1.1694 top1=99.32% | val loss=1.3974 top1=93.37% top5=97.33% | lr=3.39e-04 | 156s
# 2026-07-04 15:04:19 | INFO     | train | Epoch  69/150 | train loss=1.1685 top1=99.31% | val loss=1.4138 top1=93.20% top5=96.74% | lr=3.34e-04 | 157s
# 2026-07-04 15:06:56 | INFO     | train | Epoch  70/150 | train loss=1.1691 top1=99.19% | val loss=1.3940 top1=93.37% top5=96.74% | lr=3.29e-04 | 157s
# 2026-07-04 15:09:34 | INFO     | train | Epoch  71/150 | train loss=1.1587 top1=99.49% | val loss=1.3926 top1=93.72% top5=96.39% | lr=3.24e-04 | 158s
# 2026-07-04 15:12:12 | INFO     | train | Epoch  72/150 | train loss=1.1589 top1=99.55% | val loss=1.3980 top1=93.20% top5=96.91% | lr=3.19e-04 | 158s
# 2026-07-04 15:14:49 | INFO     | train | Epoch  73/150 | train loss=1.1603 top1=99.30% | val loss=1.4092 top1=93.72% top5=96.39% | lr=3.14e-04 | 158s
# 2026-07-04 15:17:27 | INFO     | train | Epoch  74/150 | train loss=1.1565 top1=99.40% | val loss=1.4005 top1=92.85% top5=96.39% | lr=3.09e-04 | 157s
# 2026-07-04 15:20:03 | INFO     | train | Epoch  75/150 | train loss=1.1512 top1=99.60% | val loss=1.3750 top1=93.37% top5=96.98% | lr=3.04e-04 | 156s
# 2026-07-04 15:22:39 | INFO     | train | Epoch  76/150 | train loss=1.1507 top1=99.42% | val loss=1.3869 top1=93.89% top5=96.39% | lr=2.99e-04 | 156s
# 2026-07-04 15:25:15 | INFO     | train | Epoch  77/150 | train loss=1.1464 top1=99.63% | val loss=1.3867 top1=93.72% top5=96.04% | lr=2.94e-04 | 156s
# 2026-07-04 15:27:52 | INFO     | train | Epoch  78/150 | train loss=1.1436 top1=99.61% | val loss=1.3781 top1=93.37% top5=96.81% | lr=2.89e-04 | 157s
# 2026-07-04 15:30:29 | INFO     | train | Epoch  79/150 | train loss=1.1406 top1=99.56% | val loss=1.3777 top1=93.96% top5=96.91% | lr=2.84e-04 | 157s
# 2026-07-04 15:30:29 | INFO     | train |   ★ New best val top-1: 93.96%
# 2026-07-04 15:33:06 | INFO     | train | Epoch  80/150 | train loss=1.1389 top1=99.69% | val loss=1.3927 top1=92.68% top5=96.39% | lr=2.78e-04 | 157s
# 2026-07-04 15:35:43 | INFO     | train | Epoch  81/150 | train loss=1.1403 top1=99.67% | val loss=1.3834 top1=93.03% top5=96.91% | lr=2.73e-04 | 157s
# 2026-07-04 15:38:21 | INFO     | train | Epoch  82/150 | train loss=1.1361 top1=99.64% | val loss=1.3892 top1=93.03% top5=96.91% | lr=2.68e-04 | 158s
# 2026-07-04 15:40:59 | INFO     | train | Epoch  83/150 | train loss=1.1345 top1=99.74% | val loss=1.3684 top1=93.37% top5=96.74% | lr=2.63e-04 | 158s
# 2026-07-04 15:43:35 | INFO     | train | Epoch  84/150 | train loss=1.1342 top1=99.69% | val loss=1.3759 top1=94.24% top5=96.57% | lr=2.58e-04 | 156s
# 2026-07-04 15:43:35 | INFO     | train |   ★ New best val top-1: 94.24%
# 2026-07-04 15:46:12 | INFO     | train | Epoch  85/150 | train loss=1.1337 top1=99.66% | val loss=1.3817 top1=93.20% top5=96.74% | lr=2.52e-04 | 156s
# 2026-07-04 15:48:49 | INFO     | train | Epoch  86/150 | train loss=1.1296 top1=99.65% | val loss=1.3945 top1=93.37% top5=96.74% | lr=2.47e-04 | 157s
# 2026-07-04 15:51:26 | INFO     | train | Epoch  87/150 | train loss=1.1280 top1=99.74% | val loss=1.3771 top1=93.72% top5=96.74% | lr=2.42e-04 | 157s
# 2026-07-04 15:54:04 | INFO     | train | Epoch  88/150 | train loss=1.1223 top1=99.80% | val loss=1.3671 top1=94.07% top5=96.74% | lr=2.37e-04 | 157s
# 2026-07-04 15:56:41 | INFO     | train | Epoch  89/150 | train loss=1.1255 top1=99.70% | val loss=1.3694 top1=93.37% top5=97.09% | lr=2.32e-04 | 157s
# 2026-07-04 15:59:17 | INFO     | train | Epoch  90/150 | train loss=1.1226 top1=99.83% | val loss=1.3866 top1=93.89% top5=96.57% | lr=2.27e-04 | 156s
# 2026-07-04 16:01:54 | INFO     | train | Epoch  91/150 | train loss=1.1236 top1=99.73% | val loss=1.3695 top1=93.37% top5=96.91% | lr=2.21e-04 | 157s
# 2026-07-04 16:04:31 | INFO     | train | Epoch  92/150 | train loss=1.1198 top1=99.72% | val loss=1.3913 top1=93.37% top5=96.39% | lr=2.16e-04 | 157s
# 2026-07-04 16:07:08 | INFO     | train | Epoch  93/150 | train loss=1.1170 top1=99.78% | val loss=1.3878 top1=93.72% top5=96.22% | lr=2.11e-04 | 157s
# 2026-07-04 16:09:45 | INFO     | train | Epoch  94/150 | train loss=1.1158 top1=99.84% | val loss=1.3682 top1=93.55% top5=97.09% | lr=2.06e-04 | 157s
# 2026-07-04 16:12:22 | INFO     | train | Epoch  95/150 | train loss=1.1128 top1=99.87% | val loss=1.3650 top1=94.24% top5=96.74% | lr=2.01e-04 | 157s
# 2026-07-04 16:15:00 | INFO     | train | Epoch  96/150 | train loss=1.1123 top1=99.78% | val loss=1.3702 top1=93.72% top5=96.91% | lr=1.96e-04 | 158s
# 2026-07-04 16:17:36 | INFO     | train | Epoch  97/150 | train loss=1.1122 top1=99.78% | val loss=1.3809 top1=92.85% top5=96.57% | lr=1.91e-04 | 156s
# 2026-07-04 16:20:13 | INFO     | train | Epoch  98/150 | train loss=1.1100 top1=99.83% | val loss=1.3734 top1=93.03% top5=96.91% | lr=1.86e-04 | 157s
# 2026-07-04 16:22:51 | INFO     | train | Epoch  99/150 | train loss=1.1084 top1=99.84% | val loss=1.3560 top1=93.72% top5=96.74% | lr=1.81e-04 | 158s
# 2026-07-04 16:25:28 | INFO     | train | Epoch 100/150 | train loss=1.1107 top1=99.79% | val loss=1.3649 top1=93.55% top5=96.57% | lr=1.76e-04 | 157s
# 2026-07-04 16:28:04 | INFO     | train | Epoch 101/150 | train loss=1.1066 top1=99.87% | val loss=1.3693 top1=93.37% top5=96.91% | lr=1.71e-04 | 156s
# 2026-07-04 16:30:39 | INFO     | train | Epoch 102/150 | train loss=1.1059 top1=99.89% | val loss=1.3577 top1=93.89% top5=96.74% | lr=1.66e-04 | 155s
# 2026-07-04 16:33:15 | INFO     | train | Epoch 103/150 | train loss=1.1028 top1=99.92% | val loss=1.3615 top1=94.24% top5=96.91% | lr=1.61e-04 | 156s
# 2026-07-04 16:35:53 | INFO     | train | Epoch 104/150 | train loss=1.1027 top1=99.90% | val loss=1.3638 top1=93.37% top5=96.74% | lr=1.57e-04 | 157s
# 2026-07-04 16:38:29 | INFO     | train | Epoch 105/150 | train loss=1.1013 top1=99.89% | val loss=1.3738 top1=93.37% top5=96.74% | lr=1.52e-04 | 156s
# 2026-07-04 16:41:04 | INFO     | train | Epoch 106/150 | train loss=1.1043 top1=99.87% | val loss=1.3735 top1=93.55% top5=96.74% | lr=1.47e-04 | 156s
# 2026-07-04 16:43:41 | INFO     | train | Epoch 107/150 | train loss=1.1001 top1=99.92% | val loss=1.3647 top1=93.72% top5=96.57% | lr=1.42e-04 | 157s
# 2026-07-04 16:46:17 | INFO     | train | Epoch 108/150 | train loss=1.1003 top1=99.88% | val loss=1.3693 top1=93.72% top5=96.91% | lr=1.38e-04 | 156s
# 2026-07-04 16:48:53 | INFO     | train | Epoch 109/150 | train loss=1.0966 top1=99.92% | val loss=1.3655 top1=93.72% top5=96.91% | lr=1.33e-04 | 156s
# 2026-07-04 16:48:53 | INFO     | train | Early stopping at epoch 109 (patience=25)
# 2026-07-04 16:48:53 | INFO     | train | Training complete. Best val top-1: 94.24%
# 2026-07-04 16:48:53 | INFO     | train | Best checkpoint: results/exp_col1_stgcn/checkpoints/best.pth
#
#   Total training time: 4h 46m 5s
#
# ============================================================
#  Training done!  → results/exp_col1_stgcn/
#  Next: bash scripts/05_evaluate.sh stgcn exp_col1_stgcn
# ============================================================

# %% [markdown]
# ## Step 9 — Evaluate All 3 Models

# %%
# %%bash -s "$CONFIG" "$EXP_PREFIX"
# CONFIG=$1; EXP_PREFIX=$2
# CONFIG=$CONFIG bash scripts/05_evaluate.sh bilstm      ${EXP_PREFIX}_bilstm
# CONFIG=$CONFIG bash scripts/05_evaluate.sh transformer ${EXP_PREFIX}_transformer
# CONFIG=$CONFIG bash scripts/05_evaluate.sh stgcn       ${EXP_PREFIX}_stgcn
# Out:
# ============================================================
#  Evaluation — bilstm / exp_col1_bilstm
# ============================================================
#  Checkpoint : results/exp_col1_bilstm/checkpoints/best.pth
#  Output dir : results/exp_col1_bilstm/evaluation
#
# ── Validation set ──────────────────────────────────────────
# 2026-07-04 16:49:00 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_bilstm/checkpoints/best.pth  Model: bilstm
# 2026-07-04 16:49:01 | INFO     | evaluate | Evaluating 558 samples from 'val' split
# 2026-07-04 16:49:01 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [VAL]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 95.16%
#   Top-5 Accuracy: 96.06%
#   Precision (M) : 92.72%
#   Recall    (M) : 95.14%
#   F1        (M) : 93.53%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီး ငြှိမ်း ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   လောင်စာဆီ ။                          F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   ကားသော့ ကား ထဲ မှာ ကျန် ခဲ့ လို့ ကူ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ပိုက်ဆံအိတ် လု ပြီး ပြေး သွား ပြီ ။  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   မြန်မြန်ဆန်ဆန် တောမီး ပျံ့ နိုင် တယ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လက် မီးလောင် သွား တယ် ။              F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   နှလုံး အထူးကု ဆရာဝန် နဲ့ ပြ ချင် လိ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   တနင်္လာ က နေ သောကြာ ထိ ဆို ညနေ ၄ နာ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လူနာ က ကျွန်တော့် အဒေါ် ပါ ။         F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ခင်ဗျား ခံစား နေ ရ တာ ဘယ်လောက် ကြာ   F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   အစား စား ချင် စိတ် မ ရှိ ဘူး ။       F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   မ ရ ဘူး ၊ လှုပ် ဖို့ ကြိုးစား ရင် အ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
# Confusion matrix saved → results/exp_col1_bilstm/evaluation/confusion_matrix_val.png
# Predictions saved → results/exp_col1_bilstm/evaluation/predictions_val.csv  (531/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_bilstm/evaluation
#
# ── Test set ────────────────────────────────────────────────
# 2026-07-04 16:49:08 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_bilstm/checkpoints/best.pth  Model: bilstm
# 2026-07-04 16:49:08 | INFO     | evaluate | Evaluating 558 samples from 'test' split
# 2026-07-04 16:49:08 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [TEST]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 100.00%
#   Top-5 Accuracy: 100.00%
#   Precision (M) : 100.00%
#   Recall    (M) : 100.00%
#   F1        (M) : 100.00%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီး ငြှိမ်း ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   လောင်စာဆီ ။                          F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   မ ကြာ ဘူး ၊ မိနစ် ၃၀ လောက် ဆို ရ ပြ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ လို့ ပါ ။                    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ ပြီး ခြေတောက် ခေါက် သွား တယ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   အမေ လှေကား ပေါ် က ချော်ကျ လို့ ပါ ။  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခေါင်း မှာ သွေး တွေ ထွက် နေ တယ် ။    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သူမ သတိ လစ် နေ တာ လား ။              F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဟင့်အင်း ၊ သတိ မ လစ် ပါ ဘူး ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဆရာဝန် ဘယ် အချိန် လာ မှာ လဲ ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
# Confusion matrix saved → results/exp_col1_bilstm/evaluation/confusion_matrix_test.png
# Predictions saved → results/exp_col1_bilstm/evaluation/predictions_test.csv  (558/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_bilstm/evaluation
#
# ============================================================
#  Evaluation done!  Results → results/exp_col1_bilstm/evaluation/
#   ├── metrics_val.json / metrics_test.json
#   ├── per_class_val.csv / per_class_test.csv
#   ├── confusion_matrix_test.png
#   └── predictions_test.csv
# ============================================================
# ============================================================
#  Evaluation — transformer / exp_col1_transformer
# ============================================================
#  Checkpoint : results/exp_col1_transformer/checkpoints/best.pth
#  Output dir : results/exp_col1_transformer/evaluation
#
# ── Validation set ──────────────────────────────────────────
# 2026-07-04 16:49:15 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_transformer/checkpoints/best.pth  Model: transformer
# 2026-07-04 16:49:15 | INFO     | evaluate | Evaluating 558 samples from 'val' split
# 2026-07-04 16:49:15 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [VAL]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 96.77%
#   Top-5 Accuracy: 97.49%
#   Precision (M) : 95.14%
#   Recall    (M) : 96.76%
#   F1        (M) : 95.68%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   လောင်စာဆီ ။                          F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   အမှိုက် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   အိမ် ထဲ ကို သူခိုး ဝင် သွား တယ် ။    F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ကျွန်တော် ရဲ နဲ့ တွေ့ ဖို့ လိုအပ် တ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လူ တစ်ယောက် အစာ စား ရင်း အသက်ရှု လိ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ကျွန်တော့ ညီလေး ကို ရှာ ပေး ပါ ။     F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ပိုက်ဆံအိတ် လု ပြီး ပြေး သွား ပြီ ။  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   မြန်မြန်ဆန်ဆန် တောမီး ပျံ့ နိုင် တယ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   နှလုံး အထူးကု ဆရာဝန် နဲ့ ပြ ချင် လိ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   တနင်္လာ က နေ သောကြာ ထိ ဆို ညနေ ၄ နာ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ခင်ဗျား ဘယ် ဆရာဝန် နဲ့ ပြ နေ တာ လဲ   F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လူနာ က ကျွန်တော့် အဒေါ် ပါ ။         F1=0.000  Prec=0.000  Rec=0.000  Support=1
# Confusion matrix saved → results/exp_col1_transformer/evaluation/confusion_matrix_val.png
# Predictions saved → results/exp_col1_transformer/evaluation/predictions_val.csv  (540/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_transformer/evaluation
#
# ── Test set ────────────────────────────────────────────────
# 2026-07-04 16:49:23 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_transformer/checkpoints/best.pth  Model: transformer
# 2026-07-04 16:49:23 | INFO     | evaluate | Evaluating 558 samples from 'test' split
# 2026-07-04 16:49:23 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [TEST]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 100.00%
#   Top-5 Accuracy: 100.00%
#   Precision (M) : 100.00%
#   Recall    (M) : 100.00%
#   F1        (M) : 100.00%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီး ငြှိမ်း ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   လောင်စာဆီ ။                          F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   မ ကြာ ဘူး ၊ မိနစ် ၃၀ လောက် ဆို ရ ပြ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ လို့ ပါ ။                    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ ပြီး ခြေတောက် ခေါက် သွား တယ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   အမေ လှေကား ပေါ် က ချော်ကျ လို့ ပါ ။  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခေါင်း မှာ သွေး တွေ ထွက် နေ တယ် ။    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သူမ သတိ လစ် နေ တာ လား ။              F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဟင့်အင်း ၊ သတိ မ လစ် ပါ ဘူး ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဆရာဝန် ဘယ် အချိန် လာ မှာ လဲ ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
# Confusion matrix saved → results/exp_col1_transformer/evaluation/confusion_matrix_test.png
# Predictions saved → results/exp_col1_transformer/evaluation/predictions_test.csv  (558/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_transformer/evaluation
#
# ============================================================
#  Evaluation done!  Results → results/exp_col1_transformer/evaluation/
#   ├── metrics_val.json / metrics_test.json
#   ├── per_class_val.csv / per_class_test.csv
#   ├── confusion_matrix_test.png
#   └── predictions_test.csv
# ============================================================
# ============================================================
#  Evaluation — stgcn / exp_col1_stgcn
# ============================================================
#  Checkpoint : results/exp_col1_stgcn/checkpoints/best.pth
#  Output dir : results/exp_col1_stgcn/evaluation
#
# ── Validation set ──────────────────────────────────────────
# 2026-07-04 16:49:30 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_stgcn/checkpoints/best.pth  Model: stgcn
# 2026-07-04 16:49:30 | INFO     | evaluate | Evaluating 558 samples from 'val' split
# 2026-07-04 16:49:30 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [VAL]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 94.27%
#   Top-5 Accuracy: 96.59%
#   Precision (M) : 91.67%
#   Recall    (M) : 94.24%
#   F1        (M) : 92.51%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီး ငြှိမ်း ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   အမှိုက် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   မြန်မြန်ဆန်ဆန် တောမီး ပျံ့ နိုင် တယ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ရေကြီး ရေလျှံ ခြင်း က မိလ္လာမြောင်း  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လက် မီးလောင် သွား တယ် ။              F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   နှလုံး အထူးကု ဆရာဝန် နဲ့ ပြ ချင် လိ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   တနင်္လာ က နေ သောကြာ ထိ ဆို ညနေ ၄ နာ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ညနေ ၅ နာရီ ဆို ဆေးခန်း ဖွင့် ပါ တယ်  F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   ခင်ဗျား ဘယ် ဆရာဝန် နဲ့ ပြ နေ တာ လဲ   F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   လူနာ က ကျွန်တော့် အဒေါ် ပါ ။         F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   အစား စား ချင် စိတ် မ ရှိ ဘူး ။       F1=0.000  Prec=0.000  Rec=0.000  Support=1
#   မ ရ ဘူး ၊ လှုပ် ဖို့ ကြိုးစား ရင် အ  F1=0.000  Prec=0.000  Rec=0.000  Support=1
# Confusion matrix saved → results/exp_col1_stgcn/evaluation/confusion_matrix_val.png
# Predictions saved → results/exp_col1_stgcn/evaluation/predictions_val.csv  (526/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_stgcn/evaluation
#
# ── Test set ────────────────────────────────────────────────
# 2026-07-04 16:49:39 | INFO     | evaluate | Loaded checkpoint: results/exp_col1_stgcn/checkpoints/best.pth  Model: stgcn
# 2026-07-04 16:49:40 | INFO     | evaluate | Evaluating 558 samples from 'test' split
# 2026-07-04 16:49:40 | INFO     | evaluate | Model loaded. Evaluating 558 samples…
#
# ───────────────────────────────────────────────────────
#   Evaluation Results [TEST]
# ───────────────────────────────────────────────────────
#   Samples       : 558
#   Classes       : 556
#   Top-1 Accuracy: 100.00%
#   Top-5 Accuracy: 100.00%
#   Precision (M) : 100.00%
#   Recall    (M) : 100.00%
#   F1        (M) : 100.00%
# ───────────────────────────────────────────────────────
#
# Top-10 classes by F1:
#   မီး ။                                F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီး ငြှိမ်း ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးချိတ် ။                           F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးကပ် ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ရေပုံး ။                             F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သဲ အိတ် ။                            F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ဆေးဘူး ။                       F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးသတ်ရေကန် ။                        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   မီးလောင် လွယ် သော ပစ္စည်း များ ။     F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   လောင်စာဆီ ။                          F1=1.000  Prec=1.000  Rec=1.000  Support=1
#
# Bottom-10 classes by F1:
#   မ ကြာ ဘူး ၊ မိနစ် ၃၀ လောက် ဆို ရ ပြ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ လို့ ပါ ။                    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ချော်လဲ ပြီး ခြေတောက် ခေါက် သွား တယ  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခင်ဗျား ခြေတောက် ကို ဓာတ်မှန် ရိုက်  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   အမေ လှေကား ပေါ် က ချော်ကျ လို့ ပါ ။  F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ခေါင်း မှာ သွေး တွေ ထွက် နေ တယ် ။    F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   သူမ သတိ လစ် နေ တာ လား ။              F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဟင့်အင်း ၊ သတိ မ လစ် ပါ ဘူး ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
#   ဆရာဝန် ဘယ် အချိန် လာ မှာ လဲ ။        F1=1.000  Prec=1.000  Rec=1.000  Support=1
# Confusion matrix saved → results/exp_col1_stgcn/evaluation/confusion_matrix_test.png
# Predictions saved → results/exp_col1_stgcn/evaluation/predictions_test.csv  (558/558 correct)
#
# All evaluation outputs saved to: results/exp_col1_stgcn/evaluation
#
# ============================================================
#  Evaluation done!  Results → results/exp_col1_stgcn/evaluation/
#   ├── metrics_val.json / metrics_test.json
#   ├── per_class_val.csv / per_class_test.csv
#   ├── confusion_matrix_test.png
#   └── predictions_test.csv
# ============================================================

# %% [markdown]
# ## Step 10 — Results Summary

# %%
import json
from pathlib import Path

label_name = 'Myanmar Text (Col 1)' if LABEL_COL == 1 else 'MSL Gloss (Col 2)'

exps = [
    (f'{EXP_PREFIX}_bilstm',       'BiLSTM + Attention'),
    (f'{EXP_PREFIX}_transformer',  'Transformer Encoder'),
    (f'{EXP_PREFIX}_stgcn',        'ST-GCN'),
]

print(f'\n══════════════════════════════════════════════════════════')
print(f'  MSL Recognition Results — Label: {label_name}')
print(f'══════════════════════════════════════════════════════════')
print(f"{'Model':<24} {'Val Top-1':>10} {'Test Top-1':>11} {'Test F1':>9}")
print('─' * 58)

for exp_dir, model_name in exps:
    base = Path('results') / exp_dir
    val_m  = base / 'evaluation' / 'metrics_val.json'
    test_m = base / 'evaluation' / 'metrics_test.json'
    val_top1 = test_top1 = test_f1 = '—'
    if val_m.exists():
        d = json.load(open(val_m))
        val_top1  = f"{d['top1_accuracy']*100:.2f}%"
    if test_m.exists():
        d = json.load(open(test_m))
        test_top1 = f"{d['top1_accuracy']*100:.2f}%"
        test_f1   = f"{d['f1_macro']*100:.2f}%"
    print(f"  {model_name:<22} {val_top1:>10} {test_top1:>11} {test_f1:>9}")

print('─' * 58)
print(f'  Results saved in: /kaggle/working/results/')
print(f'══════════════════════════════════════════════════════════')
# Out:
# ══════════════════════════════════════════════════════════
#   MSL Recognition Results — Label: Myanmar Text (Col 1)
# ══════════════════════════════════════════════════════════
# Model                     Val Top-1  Test Top-1   Test F1
# ──────────────────────────────────────────────────────────
#   BiLSTM + Attention         95.16%     100.00%   100.00%
#   Transformer Encoder        96.77%     100.00%   100.00%
#   ST-GCN                     94.27%     100.00%   100.00%
# ──────────────────────────────────────────────────────────
#   Results saved in: /kaggle/working/results/
# ══════════════════════════════════════════════════════════
