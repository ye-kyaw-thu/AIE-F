# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_mh = pd.read_csv('/Users/thetsusann/Desktop/AIE-F/A4/final/mental_health/data/mental_health.csv')
df_mh = df_mh.drop(columns=['Person_ID'])

corr_mh = df_mh.corr(numeric_only=True)['Depression'].drop('Depression').sort_values(ascending=False)
print(corr_mh.to_string())
# Out:
# Stress_Level                0.225461
# Daily_Screen_Time           0.123482
# Anxiety                     0.115029
# Burnout                     0.065093
# Alcohol                     0.024060
# Social_Media_Usage          0.020670
# Caffeine_Intake             0.020637
# Work_Study_Hours           -0.000752
# Age                        -0.007106
# Night_Usage                -0.019046
# Smoking                    -0.036037
# Social_Interaction_Score   -0.038833
# Sleep_Hours                -0.076989

# %%
plt.figure(figsize=(10,6))
corr_mh.plot(kind='bar', color=['#E8604C' if x > 0 else '#0D6E7E' for x in corr])
plt.title('Feature Correlation with Depression')
plt.axhline(0, color='black', linewidth=0.8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_mh.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Full Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
df_bank = pd.read_csv('/Users/thetsusann/Desktop/AIE-F/A4/final/banking/data/bank_processed.csv')

corr_bank = df_bank.corr(numeric_only=True)['deposit'].drop('deposit').sort_values(ascending=False)
print(corr_bank.to_string())
# Out:
# pdays        0.151593
# previous     0.139867
# education    0.095948
# balance      0.081129
# marital      0.067610
# job          0.063395
# age          0.034901
# month       -0.037121
# default     -0.040680
# day         -0.056326
# loan        -0.110580
# poutcome    -0.122369
# campaign    -0.128081
# housing     -0.203888
# contact     -0.249847

# %%
plt.figure(figsize=(10,6))
corr_bank.plot(kind='bar', color=['#E8604C' if x > 0 else '#0D6E7E' for x in corr])
plt.title('Feature Correlation with Deposit')
plt.axhline(0, color='black', linewidth=0.8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_bank.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm', center=0)
plt.title('Full Correlation Matrix - Banking')
plt.tight_layout()
plt.show()
